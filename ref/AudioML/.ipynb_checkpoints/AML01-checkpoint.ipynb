# %%
# !pip install audiolm-pytorch
# Out:
# Collecting audiolm-pytorch
#   Downloading audiolm_pytorch-2.1.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting accelerate>=0.24.0 (from audiolm-pytorch)
#   Downloading accelerate-1.0.1-py3-none-any.whl.metadata (19 kB)
# Collecting beartype>=0.16.1 (from audiolm-pytorch)
#   Downloading beartype-0.19.0-py3-none-any.whl.metadata (32 kB)
# Collecting einops>=0.7.0 (from audiolm-pytorch)
#   Downloading einops-0.8.0-py3-none-any.whl.metadata (12 kB)
# Collecting ema-pytorch>=0.2.2 (from audiolm-pytorch)
#   Downloading ema_pytorch-0.7.3-py3-none-any.whl.metadata (691 bytes)
# Collecting encodec (from audiolm-pytorch)
#   Downloading encodec-0.1.1.tar.gz (3.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 6.8 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Collecting fairseq (from audiolm-pytorch)
#   Downloading fairseq-0.12.2.tar.gz (9.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 23.6 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting wandb (from audiolm-pytorch)
#   Downloading wandb-0.18.5-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.7 kB)
# Collecting gateloop-transformer>=0.2.3 (from audiolm-pytorch)
#   Downloading gateloop_transformer-0.2.5-py3-none-any.whl.metadata (710 bytes)
# Requirement already satisfied: joblib in /home/pshower/miniconda3/envs/d2l/lib/python3.9/site-packages (from audiolm-pytorch) (1.3.2)
# Collecting local-attention>=1.9.0 (from audiolm-pytorch)
#   Downloading local_attention-1.9.15-py3-none-any.whl.metadata (683 bytes)
# Collecting pytorch-warmup (from audiolm-pytorch)
#   Downloading pytorch_warmup-0.1.1-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: scikit-learn in /home/pshower/miniconda3/envs/d2l/lib/python3.9/site-packages (from audiolm-pytorch) (1.4.1.post1)
# Collecting sentencepiece (from audiolm-pytorch)
#   Downloading sentencepiece-0.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting torch>=2.1 (from audiolm-pytorch)
#   Downloading torch-2.5.0-cp39-cp39-manylinux1_x86_64.whl.metadata (28 kB)
# Requirement already satisfied: torchaudio in /home/pshower/miniconda3/envs/d2l/lib/python3.9/site-packages (from audiolm-pytorch) (2.1.2)
# Collecting transformers (from audiolm-pytorch)
#   Downloading transformers-4.46.0-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.1/44.1 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /home/pshower/miniconda3/envs/d2l/lib/python3.9/site-packages (from audiolm-pytorch) (4.66.4)
# Collecting vector-quantize-pytorch>=1.18.1 (from audiolm-pytorch)
#   Downloading vector_quantize_pytorch-1.18.5-py3-none-any.whl.metadata (28 kB)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /home/pshower/miniconda3/envs/d2l/lib/python3.9/site-packages (from accelerate>=0.24.0->audiolm-pytorch) (1.26.2)
# Requirement already satisfied: packaging>=20.0 in /home/pshower/miniconda3/envs/d2l/lib/python3.9/site-packages (from accelerate>=0.24.0->audiolm-pytorch) (23.2)
# Requirement already satisfied: psutil in /home/pshower/miniconda3/envs/d2l/lib/python3.9/site-packages (from accelerate>=0.24.0->audiolm-pytorch) (5.9.6)
# Requirement already satisfied: pyyaml in /home/pshower/miniconda3/envs/d2l/lib/python3.9/site-packages (from accelerate>=0.24.0->audiolm-pytorch) (6.0.1)
# Collecting huggingface-hub>=0.21.0 (from accelerate>=0.24.0->audiolm-pytorch)
#   Downloading huggingface_hub-0.26.1-py3-none-any.whl.metadata (13 kB)
# Collecting safetensors>=0.4.3 (from accelerate>=0.24.0->audiolm-pytorch)
#   Downloading safetensors-0.4.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting rotary-embedding-torch (from gateloop-transformer>=0.2.3->audiolm-pytorch)
#   Downloading rotary_embedding_torch-0.8.4-py3-none-any.whl.metadata (678 bytes)
# Requirement already satisfied: filelock in /home/pshower/miniconda3/envs/d2l/lib/python3.9/site-packages (from torch>=2.1->audiolm-pytorch) (3.9.0)
# Collecting typing-extensions>=4.8.0 (from torch>=2.1->audiolm-pytorch)
#   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: networkx in /home/pshower/miniconda3/envs/d2l/lib/python3.9/site-packages (from torch>=2.1->audiolm-pytorch) (3.1)
# Requirement already satisfied: jinja2 in /home/pshower/miniconda3/envs/d2l/lib/python3.9/site-packages (from torch>=2.1->audiolm-pytorch) (3.1.2)
# Collecting fsspec (from torch>=2.1->audiolm-pytorch)
#   Downloading fsspec-2024.10.0-py3-none-any.whl.metadata (11 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.1->audiolm-pytorch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.1->audiolm-pytorch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.1->audiolm-pytorch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.1->audiolm-pytorch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.1->audiolm-pytorch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.1->audiolm-pytorch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.1->audiolm-pytorch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.1->audiolm-pytorch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.1->audiolm-pytorch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch>=2.1->audiolm-pytorch)
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch>=2.1->audiolm-pytorch)
#   Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.1->audiolm-pytorch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.1.0 (from torch>=2.1->audiolm-pytorch)
#   Downloading triton-3.1.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# Collecting sympy==1.13.1 (from torch>=2.1->audiolm-pytorch)
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/pshower/miniconda3/envs/d2l/lib/python3.9/site-packages (from sympy==1.13.1->torch>=2.1->audiolm-pytorch) (1.3.0)
# Collecting einx>=0.3.0 (from vector-quantize-pytorch>=1.18.1->audiolm-pytorch)
#   Downloading einx-0.3.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: cffi in /home/pshower/miniconda3/envs/d2l/lib/python3.9/site-packages (from fairseq->audiolm-pytorch) (1.15.1)
# Requirement already satisfied: cython in /home/pshower/miniconda3/envs/d2l/lib/python3.9/site-packages (from fairseq->audiolm-pytorch) (3.0.8)
# Collecting hydra-core<1.1,>=1.0.7 (from fairseq->audiolm-pytorch)
#   Downloading hydra_core-1.0.7-py3-none-any.whl.metadata (3.7 kB)
# Collecting omegaconf<2.1 (from fairseq->audiolm-pytorch)
#   Downloading omegaconf-2.0.6-py3-none-any.whl.metadata (3.0 kB)
# Collecting regex (from fairseq->audiolm-pytorch)
#   Downloading regex-2024.9.11-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 3.6 MB/s eta 0:00:00
# Collecting sacrebleu>=1.4.12 (from fairseq->audiolm-pytorch)
#   Downloading sacrebleu-2.4.3-py3-none-any.whl.metadata (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 4.3 MB/s eta 0:00:00
# Collecting bitarray (from fairseq->audiolm-pytorch)
#   Downloading bitarray-3.0.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (32 kB)
# Requirement already satisfied: scipy>=1.6.0 in /home/pshower/miniconda3/envs/d2l/lib/python3.9/site-packages (from scikit-learn->audiolm-pytorch) (1.11.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/pshower/miniconda3/envs/d2l/lib/python3.9/site-packages (from scikit-learn->audiolm-pytorch) (3.3.0)
# Requirement already satisfied: requests in /home/pshower/miniconda3/envs/d2l/lib/python3.9/site-packages (from transformers->audiolm-pytorch) (2.25.1)
# Collecting tokenizers<0.21,>=0.20 (from transformers->audiolm-pytorch)
#   Downloading tokenizers-0.20.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting click!=8.0.0,>=7.1 (from wandb->audiolm-pytorch)
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting docker-pycreds>=0.4.0 (from wandb->audiolm-pytorch)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting gitpython!=3.1.29,>=1.0.0 (from wandb->audiolm-pytorch)
#   Downloading GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: platformdirs in /home/pshower/miniconda3/envs/d2l/lib/python3.9/site-packages (from wandb->audiolm-pytorch) (4.0.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.15.0 in /home/pshower/miniconda3/envs/d2l/lib/python3.9/site-packages (from wandb->audiolm-pytorch) (4.25.3)
# Collecting sentry-sdk>=2.0.0 (from wandb->audiolm-pytorch)
#   Downloading sentry_sdk-2.17.0-py2.py3-none-any.whl.metadata (9.8 kB)
# Collecting setproctitle (from wandb->audiolm-pytorch)
#   Downloading setproctitle-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.9 kB)
# Requirement already satisfied: setuptools in /home/pshower/miniconda3/envs/d2l/lib/python3.9/site-packages (from wandb->audiolm-pytorch) (69.1.1)
# Requirement already satisfied: six>=1.4.0 in /home/pshower/miniconda3/envs/d2l/lib/python3.9/site-packages (from docker-pycreds>=0.4.0->wandb->audiolm-pytorch) (1.15.0)
# Collecting frozendict (from einx>=0.3.0->vector-quantize-pytorch>=1.18.1->audiolm-pytorch)
#   Downloading frozendict-2.4.6-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (23 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.29,>=1.0.0->wandb->audiolm-pytorch)
#   Downloading gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Collecting antlr4-python3-runtime==4.8 (from hydra-core<1.1,>=1.0.7->fairseq->audiolm-pytorch)
#   Downloading antlr4-python3-runtime-4.8.tar.gz (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.4/112.4 kB 10.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/pshower/miniconda3/envs/d2l/lib/python3.9/site-packages (from requests->transformers->audiolm-pytorch) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /home/pshower/miniconda3/envs/d2l/lib/python3.9/site-packages (from requests->transformers->audiolm-pytorch) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/pshower/miniconda3/envs/d2l/lib/python3.9/site-packages (from requests->transformers->audiolm-pytorch) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /home/pshower/miniconda3/envs/d2l/lib/python3.9/site-packages (from requests->transformers->audiolm-pytorch) (2023.11.17)
# Collecting portalocker (from sacrebleu>=1.4.12->fairseq->audiolm-pytorch)
#   Downloading portalocker-2.10.1-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /home/pshower/miniconda3/envs/d2l/lib/python3.9/site-packages (from sacrebleu>=1.4.12->fairseq->audiolm-pytorch) (0.9.0)
# Collecting colorama (from sacrebleu>=1.4.12->fairseq->audiolm-pytorch)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: lxml in /home/pshower/miniconda3/envs/d2l/lib/python3.9/site-packages (from sacrebleu>=1.4.12->fairseq->audiolm-pytorch) (5.2.2)
# Requirement already satisfied: pycparser in /home/pshower/miniconda3/envs/d2l/lib/python3.9/site-packages (from cffi->fairseq->audiolm-pytorch) (2.21)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/pshower/miniconda3/envs/d2l/lib/python3.9/site-packages (from jinja2->torch>=2.1->audiolm-pytorch) (2.1.1)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->audiolm-pytorch)
#   Downloading smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Downloading audiolm_pytorch-2.1.0-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 3.8 MB/s eta 0:00:00
# Downloading accelerate-1.0.1-py3-none-any.whl (330 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 330.9/330.9 kB 21.4 MB/s eta 0:00:00
# Downloading beartype-0.19.0-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 18.0 MB/s eta 0:00:00a 0:00:01
# Downloading einops-0.8.0-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 3.8 MB/s eta 0:00:00
# Downloading ema_pytorch-0.7.3-py3-none-any.whl (9.6 kB)
# Downloading gateloop_transformer-0.2.5-py3-none-any.whl (10 kB)
# Downloading local_attention-1.9.15-py3-none-any.whl (9.0 kB)
# Downloading torch-2.5.0-cp39-cp39-manylinux1_x86_64.whl (906.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.5/906.5 MB 1.3 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 10.6 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 22.5 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 20.7 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 25.3 MB/s eta 0:00:0000:01
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 783.9 kB/s eta 0:00:0000:0100:01
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 17.2 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 16.2 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 17.5 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 16.5 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 15.0 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 19.6 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 9.3 MB/s eta 0:00:00
# Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 20.9 MB/s eta 0:00:00a 0:00:01
# Downloading triton-3.1.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (209.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 6.9 MB/s eta 0:00:00:00:0100:01
# Downloading vector_quantize_pytorch-1.18.5-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 549.7 kB/s eta 0:00:0000:01
# Downloading pytorch_warmup-0.1.1-py3-none-any.whl (6.6 kB)
# Downloading sentencepiece-0.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 10.0 MB/s eta 0:00:0000:0100:01
# Downloading transformers-4.46.0-py3-none-any.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 3.1 MB/s eta 0:00:00:00:010:01
# Downloading wandb-0.18.5-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 23.2 MB/s eta 0:00:0000:0100:01
# Downloading click-8.1.7-py3-none-any.whl (97 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 10.4 MB/s eta 0:00:00
# Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Downloading einx-0.3.0-py3-none-any.whl (102 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.0/103.0 kB 10.5 MB/s eta 0:00:00
# Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 13.8 MB/s eta 0:00:00
# Downloading huggingface_hub-0.26.1-py3-none-any.whl (447 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 447.4/447.4 kB 23.7 MB/s eta 0:00:00
# Downloading fsspec-2024.10.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.6/179.6 kB 16.3 MB/s eta 0:00:00
# Downloading hydra_core-1.0.7-py3-none-any.whl (123 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.8/123.8 kB 12.2 MB/s eta 0:00:00
# Downloading omegaconf-2.0.6-py3-none-any.whl (36 kB)
# Downloading regex-2024.9.11-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (781 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 782.0/782.0 kB 25.2 MB/s eta 0:00:00
# Downloading sacrebleu-2.4.3-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.0/104.0 kB 11.5 MB/s eta 0:00:00
# Downloading safetensors-0.4.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (436 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 436.1/436.1 kB 30.7 MB/s eta 0:00:00
# Downloading sentry_sdk-2.17.0-py2.py3-none-any.whl (314 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.5/314.5 kB 18.6 MB/s eta 0:00:00
# Downloading tokenizers-0.20.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 21.7 MB/s eta 0:00:00a 0:00:01
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading bitarray-3.0.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (276 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 276.1/276.1 kB 18.3 MB/s eta 0:00:00
# Downloading rotary_embedding_torch-0.8.4-py3-none-any.whl (5.6 kB)
# Downloading setproctitle-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 5.5 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading frozendict-2.4.6-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.9/116.9 kB 12.0 MB/s eta 0:00:00
# Downloading portalocker-2.10.1-py3-none-any.whl (18 kB)
# Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Building wheels for collected packages: encodec, fairseq, antlr4-python3-runtime
#   Building wheel for encodec (setup.py) ... done
#   Created wheel for encodec: filename=encodec-0.1.1-py3-none-any.whl size=45760 sha256=df42e4dbd3a3932fcf7608bd1df8508334cc1953aefa79526c787d6e81afc8d9
#   Stored in directory: /home/pshower/.cache/pip/wheels/1d/9d/20/489d6aafffb505e18fcfcfbe722562f91c26af0a8a6da7d00b
#   Building wheel for fairseq (pyproject.toml) ... done
#   Created wheel for fairseq: filename=fairseq-0.12.2-cp39-cp39-linux_x86_64.whl size=10417114 sha256=16301bc0e3058401105de7cdacf46d2a3dfb2de321367762d8dae6cb42e76eda
#   Stored in directory: /home/pshower/.cache/pip/wheels/59/35/87/2baf2e4ad37c83fd698c486b3d39f0e7022226fa52ab469c31
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.8-py3-none-any.whl size=141209 sha256=5135d28983d59f11aec714eec31a56a395645018e520096f8479ccb1c60d5e48
#   Stored in directory: /home/pshower/.cache/pip/wheels/42/3c/ae/14db087e6018de74810afe32eb6ac890ef9c68ba19b00db97a
# Successfully built encodec fairseq antlr4-python3-runtime
# DEPRECATION: omegaconf 2.0.6 has a non-standard dependency specifier PyYAML>=5.1.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of omegaconf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: sentencepiece, bitarray, antlr4-python3-runtime, typing-extensions, triton, sympy, smmap, setproctitle, sentry-sdk, safetensors, regex, portalocker, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, fsspec, frozendict, einops, docker-pycreds, colorama, click, beartype, sacrebleu, omegaconf, nvidia-cusparse-cu12, nvidia-cudnn-cu12, huggingface-hub, gitdb, einx, tokenizers, nvidia-cusolver-cu12, hydra-core, gitpython, wandb, transformers, torch, vector-quantize-pytorch, rotary-embedding-torch, pytorch-warmup, local-attention, ema-pytorch, accelerate, gateloop-transformer, fairseq, encodec, audiolm-pytorch
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.3.0
#     Uninstalling typing_extensions-4.3.0:
#       Successfully uninstalled typing_extensions-4.3.0
#   Attempting uninstall: triton
#     Found existing installation: triton 2.1.0
#     Uninstalling triton-2.1.0:
#       Successfully uninstalled triton-2.1.0
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.11.1
#     Uninstalling sympy-1.11.1:
#       Successfully uninstalled sympy-1.11.1
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.0
#     Uninstalling torch-1.12.0:
#       Successfully uninstalled torch-1.12.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.13.0 requires torch==1.12.0, but you have torch 2.5.0 which is incompatible.
# Successfully installed accelerate-1.0.1 antlr4-python3-runtime-4.8 audiolm-pytorch-2.1.0 beartype-0.19.0 bitarray-3.0.0 click-8.1.7 colorama-0.4.6 docker-pycreds-0.4.0 einops-0.8.0 einx-0.3.0 ema-pytorch-0.7.3 encodec-0.1.1 fairseq-0.12.2 frozendict-2.4.6 fsspec-2024.10.0 gateloop-transformer-0.2.5 gitdb-4.0.11 gitpython-3.1.43 huggingface-hub-0.26.1 hydra-core-1.0.7 local-attention-1.9.15 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.4.127 omegaconf-2.0.6 portalocker-2.10.1 pytorch-warmup-0.1.1 regex-2024.9.11 rotary-embedding-torch-0.8.4 sacrebleu-2.4.3 safetensors-0.4.5 sentencepiece-0.2.0 sentry-sdk-2.17.0 setproctitle-1.3.3 smmap-5.0.1 sympy-1.13.1 tokenizers-0.20.1 torch-2.1.2 transformers-4.46.0 triton-3.1.0 typing-extensions-4.12.2 vector-quantize-pytorch-1.18.5 wandb-0.18.5

# %%
from audiolm_pytorch import EncodecWrapper
encodec = EncodecWrapper()
# Now you can use the encodec variable in the same way you'd use the soundstream variables below.
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from audiolm_pytorch import EncodecWrapper
#       2 encodec = EncodecWrapper()
#       3 # Now you can use the encodec variable in the same way you'd use the soundstream variables below.
#
# File ~/miniconda3/envs/d2l/lib/python3.9/site-packages/audiolm_pytorch/__init__.py:1
# ----> 1 import torch
#       2 from packaging import version
#       4 if version.parse(torch.__version__) >= version.parse('2.0.0'):
#
# File ~/miniconda3/envs/d2l/lib/python3.9/site-packages/torch/__init__.py:1955
#    1951         raise RuntimeError("Unable to find torch_shm_manager at " + path)
#    1952     return path.encode("utf-8")
# -> 1955 _C._initExtension(_manager_path())
#    1957 del _manager_path
#    1959 # Appease the type checker: it can't deal with direct setting of globals().
#    1960 # Note that we will see "too many" functions when reexporting this way; there
#    1961 # is not a good way to fix this problem.  Perhaps, try to redesign VariableFunctions
#    1962 # so that this import is good enough
#
# File ~/miniconda3/envs/d2l/lib/python3.9/site-packages/torch/cuda/__init__.py:1292
#    1288     default_generator = _get_generator(final_device)
#    1289     return default_generator.get_offset()
# -> 1292 from .memory import *  # noqa: F403
#    1293 from .random import *  # noqa: F403
#    1296 ################################################################################
#    1297 # Define Storage and Tensor classes
#    1298 ################################################################################
#
# File ~/miniconda3/envs/d2l/lib/python3.9/site-packages/torch/cuda/memory.py:12
#      10 from inspect import signature
#      11 from typing import Any, Dict, Optional, Tuple, Union
# ---> 12 from typing_extensions import deprecated
#      14 import torch
#      15 from torch import _C
#
# ImportError: cannot import name 'deprecated' from 'typing_extensions' (/home/pshower/miniconda3/envs/d2l/lib/python3.9/site-packages/typing_extensions.py)
