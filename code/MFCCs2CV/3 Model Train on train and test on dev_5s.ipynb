# %% [markdown]
# # 2 Model Train
# - 使用CV方法做训练

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import matplotlib.pyplot as plt

DATA_PATH = "data_add_train_5s.json"

def load_data(data_path):
    """Loads training dataset from json file
    
        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    
    """
    with open(data_path, "r") as fp:
        data = json.load(fp)
        
    X = np.array(data["mfcc"])
    y = np.array(data["labels"])
    return X, y

def prepare_datasets(test_size, validation_size):
    
    # load data
    X, y = load_data(DATA_PATH)
    
    # create train/test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = test_size)
    
    # create train/validation split
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size = validation_size)
    
    return (X_train, X_validation, X_test, y_train, y_validation, y_test)

def build_model(input_shape):
    """
    Generates RNN-LSTM model
    
    :param input_shape (tuple): Shape of input set
    :return model: RNN-LSTM model
    """
    
    # create model
    model = keras.Sequential()
    
    # 3 LSTM layers
    model.add(keras.layers.LSTM(512, input_shape = input_shape, return_sequences = True))
    model.add(keras.layers.LSTM(256))
    
    # dense layers
    model.add(keras.layers.Dense(128, activation = 'relu'))
    model.add(keras.layers.Dropout(0.3))
    # dense layers
    model.add(keras.layers.Dense(32, activation = 'relu'))
    model.add(keras.layers.Dropout(0.3))
    
    # output layer
    model.add(keras.layers.Dense(2, activation = 'softmax'))
    
    return model
    
    
def plot_history(history):
    
    fig, axs = plt.subplots(2)
    plt.figure(dpi=450)
    # create accuracy subplot
    axs[0].plot(history.history["accuracy"], label = "train accuracy")
    axs[0].plot(history.history["val_accuracy"], label = "test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc = "lower right")
    axs[0].set_title("Accuracy eval")
    
    # create accuracy subplot
    axs[1].plot(history.history["loss"], label = "train error")
    axs[1].plot(history.history["val_loss"], label = "test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc = "upper right")
    axs[1].set_title("Error eval")
    
    plt.show()
    
def predict(model, X, y):
    
    X = X[np.newaxis, ...]
    
    # prediction = [ [0.1, 0.2, ...]]
    prediction = model.predict(X) # X -> (1, 130, 13, 1)
    
    # extract index with max value
    predicted_index = np.argmax(prediction, axis = 1) #[4]
    print("Expected index: {}, Predicted index: {}".format(y,  predicted_index))

# %%
if __name__ == "__main__":
    
    # create train, validation and test sets
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.05, 0.15)
    
    # build the CNN net
    input_shape = (X_train.shape[1], X_train.shape[2]) # 130, 13
    model = build_model(input_shape)
    
    # compile the network
    optimizer = keras.optimizers.Adam(learning_rate = 0.00001)
    model.compile(optimizer = optimizer, loss = "sparse_categorical_crossentropy", metrics = ['accuracy'])
    model.summary()
    
    # train the RNN-LSTM
    history = model.fit(X_train, y_train, validation_data = (X_validation, y_validation), batch_size = 32, epochs = 200)
    
    # evaluate the RNN-LSTM on the test set
    test_error, test_accuracy = model.evaluate(X_test, y_test, verbose = 1)
    print("Accuracy on test set is: {}".format(test_accuracy))
    
    # make prediction on a sample
    X = X_test[0]
    y = y_test[0]

    predict(model, X, y)
    
    # plot accuracy and error over the epochs
    plot_history(history)
# Out:
# 2024-12-06 21:27:14.384502: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-12-06 21:27:14.439363: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-12-06 21:27:14.439755: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-12-06 21:27:14.441554: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-06 21:27:14.509899: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-12-06 21:27:14.510831: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-12-06 21:27:14.511567: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-12-06 21:27:15.831091: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-12-06 21:27:15.831812: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-12-06 21:27:15.831830: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1609] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-12-06 21:27:15.832534: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-12-06 21:27:15.833315: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1613 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 44, 512)           1077248
#
#  lstm_1 (LSTM)               (None, 256)               787456
#
#  dense (Dense)               (None, 128)               32896
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 32)                4128
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 1,901,794
# Trainable params: 1,901,794
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 2024-12-06 21:27:19.594029: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8101
# 2024-12-06 21:27:21.173496: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 1722/1722 [==============================] - 38s 19ms/step - loss: 0.1591 - accuracy: 0.9472 - val_loss: 0.0568 - val_accuracy: 0.9762
# Epoch 2/200
# 1722/1722 [==============================] - 33s 19ms/step - loss: 0.0443 - accuracy: 0.9871 - val_loss: 0.0293 - val_accuracy: 0.9880
# Epoch 3/200
# 1722/1722 [==============================] - 34s 20ms/step - loss: 0.0280 - accuracy: 0.9920 - val_loss: 0.0194 - val_accuracy: 0.9926
# Epoch 4/200
# 1722/1722 [==============================] - 34s 20ms/step - loss: 0.0202 - accuracy: 0.9941 - val_loss: 0.0148 - val_accuracy: 0.9944
# Epoch 5/200
# 1722/1722 [==============================] - 35s 20ms/step - loss: 0.0169 - accuracy: 0.9949 - val_loss: 0.0127 - val_accuracy: 0.9952
# Epoch 6/200
# 1722/1722 [==============================] - 34s 20ms/step - loss: 0.0126 - accuracy: 0.9961 - val_loss: 0.0124 - val_accuracy: 0.9955
# Epoch 7/200
# 1722/1722 [==============================] - 36s 21ms/step - loss: 0.0114 - accuracy: 0.9968 - val_loss: 0.0158 - val_accuracy: 0.9953
# Epoch 8/200
# 1722/1722 [==============================] - 35s 20ms/step - loss: 0.0108 - accuracy: 0.9970 - val_loss: 0.0113 - val_accuracy: 0.9965
# Epoch 9/200
# 1722/1722 [==============================] - 36s 21ms/step - loss: 0.0087 - accuracy: 0.9975 - val_loss: 0.0211 - val_accuracy: 0.9944
# Epoch 10/200
# 1722/1722 [==============================] - 35s 20ms/step - loss: 0.0073 - accuracy: 0.9978 - val_loss: 0.0080 - val_accuracy: 0.9973
# Epoch 11/200
# 1722/1722 [==============================] - 34s 20ms/step - loss: 0.0071 - accuracy: 0.9977 - val_loss: 0.0083 - val_accuracy: 0.9974
# Epoch 12/200
# 1722/1722 [==============================] - 33s 19ms/step - loss: 0.0062 - accuracy: 0.9979 - val_loss: 0.0081 - val_accuracy: 0.9974
# Epoch 13/200
# 1722/1722 [==============================] - 35s 20ms/step - loss: 0.0053 - accuracy: 0.9985 - val_loss: 0.0135 - val_accuracy: 0.9955
# Epoch 14/200
# 1722/1722 [==============================] - 35s 20ms/step - loss: 0.0056 - accuracy: 0.9984 - val_loss: 0.0081 - val_accuracy: 0.9974
# Epoch 15/200
# 1722/1722 [==============================] - 36s 21ms/step - loss: 0.0049 - accuracy: 0.9985 - val_loss: 0.0186 - val_accuracy: 0.9937
# Epoch 16/200
# 1722/1722 [==============================] - 40s 23ms/step - loss: 0.0039 - accuracy: 0.9989 - val_loss: 0.0065 - val_accuracy: 0.9977
# Epoch 17/200
# 1722/1722 [==============================] - 38s 22ms/step - loss: 0.0035 - accuracy: 0.9989 - val_loss: 0.0070 - val_accuracy: 0.9977
# Epoch 18/200
# 1722/1722 [==============================] - 38s 22ms/step - loss: 0.0029 - accuracy: 0.9992 - val_loss: 0.0085 - val_accuracy: 0.9981
# Epoch 19/200
# 1722/1722 [==============================] - 40s 23ms/step - loss: 0.0041 - accuracy: 0.9987 - val_loss: 0.0060 - val_accuracy: 0.9983
# Epoch 20/200
# 1722/1722 [==============================] - 36s 21ms/step - loss: 0.0030 - accuracy: 0.9991 - val_loss: 0.0074 - val_accuracy: 0.9981
# Epoch 21/200
# 1722/1722 [==============================] - 35s 20ms/step - loss: 0.0032 - accuracy: 0.9991 - val_loss: 0.0056 - val_accuracy: 0.9984
# Epoch 22/200
# 1722/1722 [==============================] - 36s 21ms/step - loss: 0.0023 - accuracy: 0.9993 - val_loss: 0.0063 - val_accuracy: 0.9983
# Epoch 23/200
# 1722/1722 [==============================] - 34s 20ms/step - loss: 0.0025 - accuracy: 0.9992 - val_loss: 0.0060 - val_accuracy: 0.9985
# Epoch 24/200
# 1722/1722 [==============================] - 35s 21ms/step - loss: 0.0025 - accuracy: 0.9992 - val_loss: 0.0079 - val_accuracy: 0.9975
# Epoch 25/200
# 1722/1722 [==============================] - 34s 20ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.
- accuracy: 1.0000 - val_loss: 0.0078 - val_accuracy: 0.9987
# Epoch 81/200
# 1722/1722 [==============================] - 34s 20ms/step - loss: 8.1164e-04 - accuracy: 0.9998 - val_loss: 0.0095 - val_accuracy: 0.9986
# Epoch 82/200
# 1722/1722 [==============================] - 33s 19ms/step - loss: 1.1659e-04 - accuracy: 1.0000 - val_loss: 0.0090 - val_accuracy: 0.9989
# Epoch 83/200
# 1722/1722 [==============================] - 34s 20ms/step - loss: 1.6738e-05 - accuracy: 1.0000 - val_loss: 0.0084 - val_accuracy: 0.9990
# Epoch 84/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 5.6642e-04 - accuracy: 0.9998 - val_loss: 0.0112 - val_accuracy: 0.9979
# Epoch 85/200
# 1722/1722 [==============================] - 34s 20ms/step - loss: 6.4954e-04 - accuracy: 0.9998 - val_loss: 0.0085 - val_accuracy: 0.9987
# Epoch 86/200
# 1722/1722 [==============================] - 33s 19ms/step - loss: 2.8649e-05 - accuracy: 1.0000 - val_loss: 0.0094 - val_accuracy: 0.9987
# Epoch 87/200
# 1722/1722 [==============================] - 33s 19ms/step - loss: 1.5739e-05 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 0.9985
# Epoch 88/200
# 1722/1722 [==============================] - 32s 18ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0138 - val_accuracy: 0.9975
# Epoch 89/200
# 1722/1722 [==============================] - 33s 19ms/step - loss: 1.9963e-04 - accuracy: 0.9999 - val_loss: 0.0079 - val_accuracy: 0.9986
# Epoch 90/200
# 1722/1722 [==============================] - 33s 19ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.0123 - val_accuracy: 0.9980
# Epoch 91/200
# 1722/1722 [==============================] - 36s 21ms/step - loss: 8.4183e-04 - accuracy: 0.9998 - val_loss: 0.0074 - val_accuracy: 0.9987
# Epoch 92/200
# 1722/1722 [==============================] - 36s 21ms/step - loss: 3.9769e-05 - accuracy: 1.0000 - val_loss: 0.0071 - val_accuracy: 0.9983
# Epoch 93/200
# 1722/1722 [==============================] - 35s 21ms/step - loss: 6.6624e-05 - accuracy: 1.0000 - val_loss: 0.0314 - val_accuracy: 0.9959
# Epoch 94/200
# 1722/1722 [==============================] - 94s 54ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0094 - val_accuracy: 0.9985
# Epoch 95/200
# 1722/1722 [==============================] - 32s 18ms/step - loss: 1.1501e-04 - accuracy: 1.0000 - val_loss: 0.0108 - val_accuracy: 0.9983
# Epoch 96/200
# 1722/1722 [==============================] - 32s 18ms/step - loss: 1.4507e-05 - accuracy: 1.0000 - val_loss: 0.0099 - val_accuracy: 0.9987
# Epoch 97/200
# 1722/1722 [==============================] - 33s 19ms/step - loss: 8.6314e-06 - accuracy: 1.0000 - val_loss: 0.0103 - val_accuracy: 0.9985
# Epoch 98/200
# 1722/1722 [==============================] - 33s 19ms/step - loss: 0.0020 - accuracy: 0.9996 - val_loss: 0.0141 - val_accuracy: 0.9979
# Epoch 99/200
# 1722/1722 [==============================] - 33s 19ms/step - loss: 6.2461e-04 - accuracy: 0.9998 - val_loss: 0.0118 - val_accuracy: 0.9980
# Epoch 100/200
# 1722/1722 [==============================] - 33s 19ms/step - loss: 3.7861e-05 - accuracy: 1.0000 - val_loss: 0.0101 - val_accuracy: 0.9986
# Epoch 101/200
# 1722/1722 [==============================] - 33s 19ms/step - loss: 1.6671e-05 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9985
# Epoch 102/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 9.5655e-06 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9985
# Epoch 103/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 6.3063e-06 - accuracy: 1.0000 - val_loss: 0.0107 - val_accuracy: 0.9988
# Epoch 104/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 4.4751e-04 - accuracy: 0.9999 - val_loss: 0.0290 - val_accuracy: 0.9959
# Epoch 105/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0132 - val_accuracy: 0.9979
# Epoch 106/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 3.7315e-04 - accuracy: 0.9998 - val_loss: 0.0113 - val_accuracy: 0.9985
# Epoch 107/200
# 1722/1722 [==============================] - 36s 21ms/step - loss: 5.5024e-04 - accuracy: 0.9999 - val_loss: 0.0118 - val_accuracy: 0.9985
# Epoch 108/200
# 1722/1722 [==============================] - 34s 20ms/step - loss: 2.0960e-05 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9985
# Epoch 109/200
# 1722/1722 [==============================] - 33s 19ms/step - loss: 7.9896e-06 - accuracy: 1.0000 - val_loss: 0.0108 - val_accuracy: 0.9987
# Epoch 110/200
# 1722/1722 [==============================] - 32s 18ms/step - loss: 0.0011 - accuracy: 0.9999 - val_loss: 0.0083 - val_accuracy: 0.9989
# Epoch 111/200
# 1722/1722 [==============================] - 32s 18ms/step - loss: 3.1629e-04 - accuracy: 0.9999 - val_loss: 0.0074 - val_accuracy: 0.9987
# Epoch 112/200
# 1722/1722 [==============================] - 33s 19ms/step - loss: 2.4344e-05 - accuracy: 1.0000 - val_loss: 0.0076 - val_accuracy: 0.9989
# Epoch 113/200
# 1722/1722 [==============================] - 33s 19ms/step - loss: 5.9855e-06 - accuracy: 1.0000 - val_loss: 0.0073 - val_accuracy: 0.9991
# Epoch 114/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 5.4439e-05 - accuracy: 1.0000 - val_loss: 0.0091 - val_accuracy: 0.9986
# Epoch 115/200
# 1722/1722 [==============================] - 33s 19ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0057 - val_accuracy: 0.9993
# Epoch 116/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.0068 - val_accuracy: 0.9989
# Epoch 117/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 2.5863e-05 - accuracy: 1.0000 - val_loss: 0.0073 - val_accuracy: 0.9988
# Epoch 118/200
# 1722/1722 [==============================] - 33s 19ms/step - loss: 1.7819e-05 - accuracy: 1.0000 - val_loss: 0.0068 - val_accuracy: 0.9992
# Epoch 119/200
# 1722/1722 [==============================] - 34s 20ms/step - loss: 8.9721e-06 - accuracy: 1.0000 - val_loss: 0.0091 - val_accuracy: 0.9986
# Epoch 120/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 6.1076e-06 - accuracy: 1.0000 - val_loss: 0.0105 - val_accuracy: 0.9989
# Epoch 121/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 3.3034e-06 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9988
# Epoch 122/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 1.8594e-06 - accuracy: 1.0000 - val_loss: 0.0133 - val_accuracy: 0.9989
# Epoch 123/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 0.0026 - accuracy: 0.9997 - val_loss: 0.0190 - val_accuracy: 0.9975
# Epoch 124/200
# 1722/1722 [==============================] - 32s 18ms/step - loss: 1.3031e-04 - accuracy: 0.9999 - val_loss: 0.0095 - val_accuracy: 0.9985
# Epoch 125/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.0100 - val_accuracy: 0.9983
# Epoch 126/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 4.1328e-05 - accuracy: 1.0000 - val_loss: 0.0117 - val_accuracy: 0.9985
# Epoch 127/200
# 1722/1722 [==============================] - 32s 18ms/step - loss: 3.1758e-05 - accuracy: 1.0000 - val_loss: 0.0117 - val_accuracy: 0.9987
# Epoch 128/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 4.3462e-06 - accuracy: 1.0000 - val_loss: 0.0128 - val_accuracy: 0.9986
# Epoch 129/200
# 1722/1722 [==============================] - 33s 19ms/step - loss: 1.8516e-04 - accuracy: 0.9999 - val_loss: 0.0129 - val_accuracy: 0.9985
# Epoch 130/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 5.9305e-04 - accuracy: 0.9998 - val_loss: 0.0105 - val_accuracy: 0.9990
# Epoch 131/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 1.5628e-05 - accuracy: 1.0000 - val_loss: 0.0103 - val_accuracy: 0.9990
# Epoch 132/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 5.6670e-06 - accuracy: 1.0000 - val_loss: 0.0109 - val_accuracy: 0.9989
# Epoch 133/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 0.0023 - accuracy: 0.9994 - val_loss: 0.0115 - val_accuracy: 0.9981
# Epoch 134/200
# 1722/1722 [==============================] - 32s 18ms/step - loss: 2.0735e-04 - accuracy: 0.9999 - val_loss: 0.0112 - val_accuracy: 0.9975
# Epoch 135/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 5.8255e-04 - accuracy: 0.9998 - val_loss: 0.0082 - val_accuracy: 0.9984
# Epoch 136/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 1.5027e-04 - accuracy: 1.0000 - val_loss: 0.0071 - val_accuracy: 0.9984
# Epoch 137/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 1.2373e-05 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 0.9988
# Epoch 138/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 8.7669e-04 - accuracy: 0.9998 - val_loss: 0.0094 - val_accuracy: 0.9978
# Epoch 139/200
# 1722/1722 [==============================] - 32s 18ms/step - loss: 2.8709e-04 - accuracy: 0.9999 - val_loss: 0.0073 - val_accuracy: 0.9986
# Epoch 140/200
# 1722/1722 [==============================] - 31s 18ms/step - loss: 4.1277e-05 - accuracy: 1.0000 - val_loss: 0.0088 - val_accuracy: 0.9986
# Epoch 141/200
# 1722/1722 [==============================] - 33s 19ms/step - loss: 6.8598e-06 - accuracy: 1.0000 - val_loss: 0.0103 - val_accuracy: 0.9985
# Epoch 142/200
# 1722/1722 [==============================] - 34s 20ms/step - loss: 5.4930e-06 - accuracy: 1.0000 - val_loss: 0.0108 - val_accuracy: 0.9985
# Epoch 143/200
# 1722/1722 [==============================] - 34s 20ms/step - loss: 6.6678e-04 - accuracy: 0.9999 - val_loss: 0.0119 - val_accuracy: 0.9981
# Epoch 144/200
# 1722/1722 [==============================] - 34s 20ms/step - loss: 6.5669e-04 - accuracy: 0.9998 - val_loss: 0.0303 - val_accuracy: 0.9963
# Epoch 145/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 1.0266e-04 - accuracy: 0.9999 - val_loss: 0.0084 - val_accuracy: 0.9989
# Epoch 146/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 1.2489e-05 - accuracy: 1.0000 - val_loss: 0.0084 - val_accuracy: 0.9986
# Epoch 147/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 5.0397e-06 - accuracy: 1.0000 - val_loss: 0.0097 - val_accuracy: 0.9985
# Epoch 148/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 4.6093e-06 - accuracy: 1.0000 - val_loss: 0.0110 - val_accuracy: 0.9984
# Epoch 149/200
# 1722/1722 [==============================] - 31s 18ms/step - loss: 4.5501e-04 - accuracy: 0.9999 - val_loss: 0.0255 - val_accuracy: 0.9960
# Epoch 150/200
# 1722/1722 [==============================] - 32s 18ms/step - loss: 4.0365e-04 - accuracy: 0.9999 - val_loss: 0.0123 - val_accuracy: 0.9986
# Epoch 151/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 7.9093e-06 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9986
# Epoch 152/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 4.8349e-06 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9986
# Epoch 153/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 2.1188e-06 - accuracy: 1.0000 - val_loss: 0.0092 - val_accuracy: 0.9988
# Epoch 154/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 9.7762e-04 - accuracy: 0.9997 - val_loss: 0.0082 - val_accuracy: 0.9986
# Epoch 155/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 2.9218e-05 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 0.9989
# Epoch 156/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 7.3027e-06 - accuracy: 1.0000 - val_loss: 0.0079 - val_accuracy: 0.9991
# Epoch 157/200
# 1722/1722 [==============================] - 32s 18ms/step - loss: 7.0554e-06 - accuracy: 1.0000 - val_loss: 0.0087 - val_accuracy: 0.9988
# Epoch 158/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0088 - val_accuracy: 0.9987
# Epoch 159/200
# 1722/1722 [==============================] - 33s 19ms/step - loss: 9.4565e-06 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 0.9986
# Epoch 160/200
# 1722/1722 [==============================] - 32s 18ms/step - loss: 1.8838e-05 - accuracy: 1.0000 - val_loss: 0.0093 - val_accuracy: 0.9989
# Epoch 161/200
# 1722/1722 [==============================] - 33s 19ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.0069 - val_accuracy: 0.9990
# Epoch 162/200
# 1722/1722 [==============================] - 32s 18ms/step - loss: 7.4891e-04 - accuracy: 0.9998 - val_loss: 0.0110 - val_accuracy: 0.9978
# Epoch 163/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 2.0075e-04 - accuracy: 0.9999 - val_loss: 0.0074 - val_accuracy: 0.9989
# Epoch 164/200
# 1722/1722 [==============================] - 33s 19ms/step - loss: 1.1648e-05 - accuracy: 1.0000 - val_loss: 0.0091 - val_accuracy: 0.9987
# Epoch 165/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 8.0205e-06 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 0.9988
# Epoch 166/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 3.8660e-06 - accuracy: 1.0000 - val_loss: 0.0088 - val_accuracy: 0.9988
# Epoch 167/200
# 1722/1722 [==============================] - 31s 18ms/step - loss: 1.7052e-06 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9989
# Epoch 168/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 9.0451e-04 - accuracy: 0.9998 - val_loss: 0.0070 - val_accuracy: 0.9991
# Epoch 169/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 5.1313e-05 - accuracy: 1.0000 - val_loss: 0.0120 - val_accuracy: 0.9986
# Epoch 170/200
# 1722/1722 [==============================] - 33s 19ms/step - loss: 6.0225e-06 - accuracy: 1.0000 - val_loss: 0.0090 - val_accuracy: 0.9991
# Epoch 171/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 4.8183e-06 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 0.9989
# Epoch 172/200
# 1722/1722 [==============================] - 33s 19ms/step - loss: 3.3889e-06 - accuracy: 1.0000 - val_loss: 0.0199 - val_accuracy: 0.9981
# Epoch 173/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 1.8554e-06 - accuracy: 1.0000 - val_loss: 0.0104 - val_accuracy: 0.9990
# Epoch 174/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 5.1847e-07 - accuracy: 1.0000 - val_loss: 0.0141 - val_accuracy: 0.9988
# Epoch 175/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 0.0016 - accuracy: 0.9998 - val_loss: 0.0107 - val_accuracy: 0.9983
# Epoch 176/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 1.8935e-05 - accuracy: 1.0000 - val_loss: 0.0110 - val_accuracy: 0.9985
# Epoch 177/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 1.6894e-05 - accuracy: 1.0000 - val_loss: 0.0098 - val_accuracy: 0.9989
# Epoch 178/200
# 1722/1722 [==============================] - 32s 18ms/step - loss: 2.3377e-06 - accuracy: 1.0000 - val_loss: 0.0095 - val_accuracy: 0.9988
# Epoch 179/200
# 1722/1722 [==============================] - 33s 19ms/step - loss: 3.7707e-06 - accuracy: 1.0000 - val_loss: 0.0088 - val_accuracy: 0.9990
# Epoch 180/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0072 - val_accuracy: 0.9991
# Epoch 181/200
# 1722/1722 [==============================] - 33s 19ms/step - loss: 1.3552e-04 - accuracy: 0.9999 - val_loss: 0.0097 - val_accuracy: 0.9980
# Epoch 182/200
# 1722/1722 [==============================] - 33s 19ms/step - loss: 6.5848e-04 - accuracy: 0.9999 - val_loss: 0.0075 - val_accuracy: 0.9989
# Epoch 183/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 5.3667e-06 - accuracy: 1.0000 - val_loss: 0.0079 - val_accuracy: 0.9989
# Epoch 184/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 4.6719e-06 - accuracy: 1.0000 - val_loss: 0.0084 - val_accuracy: 0.9988
# Epoch 185/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 2.7446e-06 - accuracy: 1.0000 - val_loss: 0.0091 - val_accuracy: 0.9989
# Epoch 186/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 1.9075e-06 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 0.9987
# Epoch 187/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.0119 - val_accuracy: 0.9989
# Epoch 188/200
# 1722/1722 [==============================] - 32s 18ms/step - loss: 9.2730e-05 - accuracy: 1.0000 - val_loss: 0.0116 - val_accuracy: 0.9985
# Epoch 189/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 5.7925e-04 - accuracy: 0.9998 - val_loss: 0.0090 - val_accuracy: 0.9989
# Epoch 190/200
# 1722/1722 [==============================] - 33s 19ms/step - loss: 6.9109e-06 - accuracy: 1.0000 - val_loss: 0.0100 - val_accuracy: 0.9987
# Epoch 191/200
# 1722/1722 [==============================] - 33s 19ms/step - loss: 3.7214e-06 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9991
# Epoch 192/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 2.6308e-06 - accuracy: 1.0000 - val_loss: 0.0095 - val_accuracy: 0.9989
# Epoch 193/200
# 1722/1722 [==============================] - 33s 19ms/step - loss: 3.5835e-06 - accuracy: 1.0000 - val_loss: 0.0097 - val_accuracy: 0.9990
# Epoch 194/200
# 1722/1722 [==============================] - 32s 18ms/step - loss: 1.4689e-06 - accuracy: 1.0000 - val_loss: 0.0135 - val_accuracy: 0.9985
# Epoch 195/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 5.9047e-07 - accuracy: 1.0000 - val_loss: 0.0118 - val_accuracy: 0.9987
# Epoch 196/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 8.6409e-04 - accuracy: 0.9998 - val_loss: 0.0386 - val_accuracy: 0.9959
# Epoch 197/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 8.4466e-04 - accuracy: 0.9998 - val_loss: 0.0106 - val_accuracy: 0.9990
# Epoch 198/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 5.7591e-06 - accuracy: 1.0000 - val_loss: 0.0106 - val_accuracy: 0.9989
# Epoch 199/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 4.4704e-06 - accuracy: 1.0000 - val_loss: 0.0106 - val_accuracy: 0.9989
# Epoch 200/200
# 1722/1722 [==============================] - 32s 19ms/step - loss: 3.3958e-06 - accuracy: 1.0000 - val_loss: 0.0104 - val_accuracy: 0.9989
# 107/107 [==============================] - 1s 8ms/step - loss: 0.0072 - accuracy: 0.9991
# Accuracy on test set is: 0.9991207718849182
# Expected index: 0, Predicted index: [0]

# %%
model.save('02_model/1205_5s.h5')
# model=keras.models.load_model('02_model/1205_5s.h5'

# %%
# model=keras.models.load_model('02_model/1205_5s.h5')

# %%
X_test_pre = model.predict(X_test)
y_pre = np.argmax(X_test_pre, axis = 1)

import sklearn.metrics as sm
matrixes = sm.confusion_matrix(y_test, y_pre)
print(matrixes)
report = sm.classification_report(y_test, y_pre)
print(report)
# Out:
# [[2991    1]
#  [   2  418]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2992
#            1       1.00      1.00      1.00       420
#
#     accuracy                           1.00      3412
#    macro avg       1.00      1.00      1.00      3412
# weighted avg       1.00      1.00      1.00      3412

# %%
X_dev, y_dev = load_data("data_add_5s.json")
X_dev.shape
# Out:
# (71785, 44, 13)

# %%
X_dev, y_dev = load_data("data_add_5s.json")
y_dev_pre = np.argmax(model.predict(X_dev), axis = 1)
matrixes = sm.confusion_matrix(y_dev, y_dev_pre)
print(matrixes)
report = sm.classification_report(y_dev, y_dev_pre)
print(report)
# Out:
# [[65151   301]
#  [  209  6124]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     65452
#            1       0.95      0.97      0.96      6333
#
#     accuracy                           0.99     71785
#    macro avg       0.97      0.98      0.98     71785
# weighted avg       0.99      0.99      0.99     71785

# %%
import sklearn.metrics as sm
X_test, y_test = load_data("data_add_test.json")
y_test_pre = np.argmax(model.predict(X_test), axis = 1)
matrixes = sm.confusion_matrix(y_test, y_test_pre)
print(matrixes)
report = sm.classification_report(y_test, y_test_pre)
print(report)

# %%
import sklearn.metrics as sm
X_test, y_test = load_data("data_add_test_25n.json")y_dev_pre_prob = model.predict(X_dev)
y_dev_pre_c = [0 if x > y - 0.9 else 1 for x, y in y_dev_pre_prob]
matrixes = sm.confusion_matrix(y_dev, y_dev_pre_c)
print(matrixes)
report = sm.classification_report(y_dev, y_dev_pre_c)
print(report)
# Out:
# [[65197   255]
#  [  244  6089]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     65452
#            1       0.96      0.96      0.96      6333
#
#     accuracy                           0.99     71785
#    macro avg       0.98      0.98      0.98     71785
# weighted avg       0.99      0.99      0.99     71785

# %%
test_error, test_accuracy = model.evaluate(X_dev, y_dev, verbose = 1)
print("Accuracy on dev set is: {}".format(test_accuracy))
# Out:
# 2244/2244 [==============================] - 18s 8ms/step - loss: 0.0758 - accuracy: 0.9929
# Accuracy on dev set is: 0.9928954243659973

# %%
# from scipy.special import softmax
from sklearn.metrics import roc_curve, auc
fpr, tpr, thresholds = roc_curve(y_dev, y_dev_pre_prob[:, 1]) 
roc_auc = auc(fpr, tpr)
print("AUC for the testing set :", roc_auc)  # 输出AUC值
# 绘制ROC曲线
plt.figure(dpi=300, figsize=(10,8))
plt.plot(fpr, tpr, color='darkorange', label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")
plt.show()
# Out:
# AUC for the testing set : 0.9986263095890402
