# %% [markdown]
# # 2 Model Train
# - 使用CV方法做训练

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import matplotlib.pyplot as plt

DATA_PATH = "data_add_train.json"

def load_data(data_path):
    """Loads training dataset from json file
    
        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    
    """
    with open(data_path, "r") as fp:
        data = json.load(fp)
        
    X = np.array(data["mfcc"])
    y = np.array(data["labels"])
    return X, y

def prepare_datasets(test_size, validation_size):
    
    # load data
    X, y = load_data(DATA_PATH)
    
    # create train/test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = test_size)
    
    # create train/validation split
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size = validation_size)
    
    return (X_train, X_validation, X_test, y_train, y_validation, y_test)

def build_model(input_shape):
    """
    Generates RNN-LSTM model
    
    :param input_shape (tuple): Shape of input set
    :return model: RNN-LSTM model
    """
    
    # create model
    model = keras.Sequential()
    
    # 3 LSTM layers
    model.add(keras.layers.LSTM(128, input_shape = input_shape, return_sequences = True))
    model.add(keras.layers.LSTM(64))
    
    # dense layers
    model.add(keras.layers.Dense(64, activation = 'relu'))
    model.add(keras.layers.Dropout(0.3))
    
    # output layer
    model.add(keras.layers.Dense(2, activation = 'softmax'))
    
    return model
    
    
def plot_history(history):
    
    fig, axs = plt.subplots(2)
    plt.figure(dpi=450)
    # create accuracy subplot
    axs[0].plot(history.history["accuracy"], label = "train accuracy")
    axs[0].plot(history.history["val_accuracy"], label = "test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc = "lower right")
    axs[0].set_title("Accuracy eval")
    
    # create accuracy subplot
    axs[1].plot(history.history["loss"], label = "train error")
    axs[1].plot(history.history["val_loss"], label = "test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc = "upper right")
    axs[1].set_title("Error eval")
    
    plt.show()
    
def predict(model, X, y):
    
    X = X[np.newaxis, ...]
    
    # prediction = [ [0.1, 0.2, ...]]
    prediction = model.predict(X) # X -> (1, 130, 13, 1)
    
    # extract index with max value
    predicted_index = np.argmax(prediction, axis = 1) #[4]
    print("Expected index: {}, Predicted index: {}".format(y,  predicted_index))

# %%
if __name__ == "__main__":
    
    # create train, validation and test sets
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.05, 0.15)
    
    # build the CNN net
    input_shape = (X_train.shape[1], X_train.shape[2]) # 130, 13
    model = build_model(input_shape)
    
    # compile the network
    optimizer = keras.optimizers.Adam(learning_rate = 0.0001)
    model.compile(optimizer = optimizer, loss = "sparse_categorical_crossentropy", metrics = ['accuracy'])
    model.summary()
    
    # train the RNN-LSTM
    history = model.fit(X_train, y_train, validation_data = (X_validation, y_validation), batch_size = 32, epochs = 100)
    
    # evaluate the RNN-LSTM on the test set
    test_error, test_accuracy = model.evaluate(X_test, y_test, verbose = 1)
    print("Accuracy on test set is: {}".format(test_accuracy))
    
    # make prediction on a sample
    X = X_test[0]
    y = y_test[0]

    predict(model, X, y)
    
    # plot accuracy and error over the epochs
    plot_history(history)
# Out:
# 2024-11-21 16:24:36.540545: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-21 16:24:36.549290: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-21 16:24:36.549954: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-21 16:24:36.550876: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-21 16:24:36.586116: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-21 16:24:36.587152: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-21 16:24:36.587776: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-21 16:24:37.258732: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-21 16:24:37.259472: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-21 16:24:37.259492: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1609] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-11-21 16:24:37.260043: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-21 16:24:37.260101: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1613 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 259, 128)          72704
#
#  lstm_1 (LSTM)               (None, 64)                49408
#
#  dense (Dense)               (None, 64)                4160
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 126,402
# Trainable params: 126,402
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 2024-11-21 16:24:40.076842: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8101
# 2024-11-21 16:24:41.021778: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 22/22 [==============================] - 5s 66ms/step - loss: 0.6740 - accuracy: 0.5930 - val_loss: 0.4717 - val_accuracy: 0.9180
# Epoch 2/100
# 22/22 [==============================] - 1s 43ms/step - loss: 0.4199 - accuracy: 0.8852 - val_loss: 0.3263 - val_accuracy: 0.9180
# Epoch 3/100
# 22/22 [==============================] - 1s 45ms/step - loss: 0.3429 - accuracy: 0.8881 - val_loss: 0.2699 - val_accuracy: 0.9180
# Epoch 4/100
# 22/22 [==============================] - 1s 42ms/step - loss: 0.2933 - accuracy: 0.8939 - val_loss: 0.2205 - val_accuracy: 0.9262
# Epoch 5/100
# 22/22 [==============================] - 1s 47ms/step - loss: 0.2332 - accuracy: 0.9230 - val_loss: 0.1557 - val_accuracy: 0.9590
# Epoch 6/100
# 22/22 [==============================] - 1s 44ms/step - loss: 0.1596 - accuracy: 0.9622 - val_loss: 0.0973 - val_accuracy: 0.9918
# Epoch 7/100
# 22/22 [==============================] - 1s 44ms/step - loss: 0.1034 - accuracy: 0.9738 - val_loss: 0.0644 - val_accuracy: 0.9918
# Epoch 8/100
# 22/22 [==============================] - 1s 44ms/step - loss: 0.0721 - accuracy: 0.9855 - val_loss: 0.0446 - val_accuracy: 0.9918
# Epoch 9/100
# 22/22 [==============================] - 1s 44ms/step - loss: 0.0479 - accuracy: 0.9942 - val_loss: 0.0305 - val_accuracy: 1.0000
# Epoch 10/100
# 22/22 [==============================] - 1s 42ms/step - loss: 0.0353 - accuracy: 0.9971 - val_loss: 0.0383 - val_accuracy: 0.9836
# Epoch 11/100
# 22/22 [==============================] - 1s 45ms/step - loss: 0.0286 - accuracy: 0.9956 - val_loss: 0.0303 - val_accuracy: 0.9918
# Epoch 12/100
# 22/22 [==============================] - 1s 41ms/step - loss: 0.0250 - accuracy: 0.9985 - val_loss: 0.0124 - val_accuracy: 1.0000
# Epoch 13/100
# 22/22 [==============================] - 1s 43ms/step - loss: 0.0159 - accuracy: 1.0000 - val_loss: 0.0148 - val_accuracy: 0.9918
# Epoch 14/100
# 22/22 [==============================] - 1s 44ms/step - loss: 0.0158 - accuracy: 0.9985 - val_loss: 0.0075 - val_accuracy: 1.0000
# Epoch 15/100
# 22/22 [==============================] - 1s 45ms/step - loss: 0.0117 - accuracy: 1.0000 - val_loss: 0.0212 - val_accuracy: 0.9918
# Epoch 16/100
# 22/22 [==============================] - 1s 46ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.0144 - val_accuracy: 0.9918
# Epoch 17/100
# 22/22 [==============================] - 1s 44ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.0144 - val_accuracy: 0.9918
# Epoch 18/100
# 22/22 [==============================] - 1s 44ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.0042 - val_accuracy: 1.0000
# Epoch 19/100
# 22/22 [==============================] - 1s 43ms/step - loss: 0.0097 - accuracy: 0.9985 - val_loss: 0.0394 - val_accuracy: 0.9836
# Epoch 20/100
# 22/22 [==============================] - 1s 43ms/step - loss: 0.0118 - accuracy: 0.9985 - val_loss: 0.0058 - val_accuracy: 1.0000
# Epoch 21/100
# 22/22 [==============================] - 1s 44ms/step - loss: 0.0075 - accuracy: 0.9985 - val_loss: 0.0787 - val_accuracy: 0.9672
# Epoch 22/100
# 22/22 [==============================] - 1s 42ms/step - loss: 0.0195 - accuracy: 0.9956 - val_loss: 0.0667 - val_accuracy: 0.9672
# Epoch 23/100
# 22/22 [==============================] - 1s 43ms/step - loss: 0.1105 - accuracy: 0.9564 - val_loss: 0.0151 - val_accuracy: 0.9918
# Epoch 24/100
# 22/22 [==============================] - 1s 42ms/step - loss: 0.0247 - accuracy: 0.9913 - val_loss: 0.0143 - val_accuracy: 0.9918
# Epoch 25/100
# 22/22 [==============================] - 1s 40ms/step - loss: 0.0109 - accuracy: 0.9985 - val_loss: 0.0055 - val_accuracy: 1.0000
# Epoch 26/100
# 22/22 [==============================] - 1s 42ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 27/100
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.0044 - val_accuracy: 1.0000
# Epoch 28/100
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 29/100
# 22/22 [==============================] - 1s 42ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 30/100
# 22/22 [==============================] - 1s 43ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 31/100
# 22/22 [==============================] - 1s 42ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 32/100
# 22/22 [==============================] - 1s 44ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 33/100
# 22/22 [==============================] - 1s 42ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 34/100
# 22/22 [==============================] - 1s 46ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 35/100
# 22/22 [==============================] - 1s 43ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 36/100
# 22/22 [==============================] - 1s 44ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 37/100
# 22/22 [==============================] - 1s 42ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 38/100
# 22/22 [==============================] - 1s 41ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 39/100
# 22/22 [==============================] - 1s 42ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 40/100
# 22/22 [==============================] - 1s 43ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 41/100
# 22/22 [==============================] - 1s 44ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 42/100
# 22/22 [==============================] - 1s 42ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 43/100
# 22/22 [==============================] - 1s 43ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 44/100
# 22/22 [==============================] - 1s 45ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 45/100
# 22/22 [==============================] - 1s 48ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 46/100
# 22/22 [==============================] - 1s 43ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 47/100
# 22/22 [==============================] - 1s 43ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 48/100
# 22/22 [==============================] - 1s 41ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 49/100
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 50/100
# 22/22 [==============================] - 1s 46ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 51/100
# 22/22 [==============================] - 1s 45ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0051 - val_accuracy: 1.0000
# Epoch 52/100
# 22/22 [==============================] - 1s 40ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0060 - val_accuracy: 1.0000
# Epoch 53/100
# 22/22 [==============================] - 1s 43ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0068 - val_accuracy: 1.0000
# Epoch 54/100
# 22/22 [==============================] - 1s 44ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 0.9918
# Epoch 55/100
# 22/22 [==============================] - 1s 40ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0097 - val_accuracy: 0.9918
# Epoch 56/100
# 22/22 [==============================] - 1s 42ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9918
# Epoch 57/100
# 22/22 [==============================] - 1s 41ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0176 - val_accuracy: 0.9918
# Epoch 58/100
# 22/22 [==============================] - 1s 43ms/step - loss: 9.2938e-04 - accuracy: 1.0000 - val_loss: 0.0387 - val_accuracy: 0.9918
# Epoch 59/100
# 22/22 [==============================] - 1s 45ms/step - loss: 0.0136 - accuracy: 0.9971 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 60/100
# 22/22 [==============================] - 1s 41ms/step - loss: 0.0242 - accuracy: 0.9956 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 61/100
# 22/22 [==============================] - 1s 44ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 62/100
# 22/22 [==============================] - 1s 42ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 9.2376e-04 - val_accuracy: 1.0000
# Epoch 63/100
# 22/22 [==============================] - 1s 44ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 7.5198e-04 - val_accuracy: 1.0000
# Epoch 64/100
# 22/22 [==============================] - 1s 46ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 7.1790e-04 - val_accuracy: 1.0000
# Epoch 65/100
# 22/22 [==============================] - 1s 41ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 6.9210e-04 - val_accuracy: 1.0000
# Epoch 66/100
# 22/22 [==============================] - 1s 43ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 6.7391e-04 - val_accuracy: 1.0000
# Epoch 67/100
# 22/22 [==============================] - 1s 40ms/step - loss: 8.3069e-04 - accuracy: 1.0000 - val_loss: 6.5691e-04 - val_accuracy: 1.0000
# Epoch 68/100
# 22/22 [==============================] - 1s 45ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 6.3703e-04 - val_accuracy: 1.0000
# Epoch 69/100
# 22/22 [==============================] - 1s 42ms/step - loss: 8.1661e-04 - accuracy: 1.0000 - val_loss: 6.1821e-04 - val_accuracy: 1.0000
# Epoch 70/100
# 22/22 [==============================] - 1s 40ms/step - loss: 8.4210e-04 - accuracy: 1.0000 - val_loss: 6.0397e-04 - val_accuracy: 1.0000
# Epoch 71/100
# 22/22 [==============================] - 1s 43ms/step - loss: 7.6833e-04 - accuracy: 1.0000 - val_loss: 5.8713e-04 - val_accuracy: 1.0000
# Epoch 72/100
# 22/22 [==============================] - 1s 40ms/step - loss: 7.8532e-04 - accuracy: 1.0000 - val_loss: 5.7091e-04 - val_accuracy: 1.0000
# Epoch 73/100
# 22/22 [==============================] - 1s 44ms/step - loss: 8.5136e-04 - accuracy: 1.0000 - val_loss: 5.6146e-04 - val_accuracy: 1.0000
# Epoch 74/100
# 22/22 [==============================] - 1s 42ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 5.4268e-04 - val_accuracy: 1.0000
# Epoch 75/100
# 22/22 [==============================] - 1s 44ms/step - loss: 6.8051e-04 - accuracy: 1.0000 - val_loss: 5.2780e-04 - val_accuracy: 1.0000
# Epoch 76/100
# 22/22 [==============================] - 1s 44ms/step - loss: 9.4097e-04 - accuracy: 1.0000 - val_loss: 5.1614e-04 - val_accuracy: 1.0000
# Epoch 77/100
# 22/22 [==============================] - 1s 41ms/step - loss: 7.8000e-04 - accuracy: 1.0000 - val_loss: 5.0482e-04 - val_accuracy: 1.0000
# Epoch 78/100
# 22/22 [==============================] - 1s 43ms/step - loss: 8.7384e-04 - accuracy: 1.0000 - val_loss: 4.9756e-04 - val_accuracy: 1.0000
# Epoch 79/100
# 22/22 [==============================] - 1s 43ms/step - loss: 7.4336e-04 - accuracy: 1.0000 - val_loss: 4.8451e-04 - val_accuracy: 1.0000
# Epoch 80/100
# 22/22 [==============================] - 1s 39ms/step - loss: 6.9857e-04 - accuracy: 1.0000 - val_loss: 4.7428e-04 - val_accuracy: 1.0000
# Epoch 81/100
# 22/22 [==============================] - 1s 44ms/step - loss: 7.8527e-04 - accuracy: 1.0000 - val_loss: 4.6687e-04 - val_accuracy: 1.0000
# Epoch 82/100
# 22/22 [==============================] - 1s 42ms/step - loss: 6.7683e-04 - accuracy: 1.0000 - val_loss: 4.5183e-04 - val_accuracy: 1.0000
# Epoch 83/100
# 22/22 [==============================] - 1s 42ms/step - loss: 6.1545e-04 - accuracy: 1.0000 - val_loss: 4.4348e-04 - val_accuracy: 1.0000
# Epoch 84/100
# 22/22 [==============================] - 1s 43ms/step - loss: 5.4723e-04 - accuracy: 1.0000 - val_loss: 4.3692e-04 - val_accuracy: 1.0000
# Epoch 85/100
# 22/22 [==============================] - 1s 41ms/step - loss: 4.3220e-04 - accuracy: 1.0000 - val_loss: 4.3565e-04 - val_accuracy: 1.0000
# Epoch 86/100
# 22/22 [==============================] - 1s 43ms/step - loss: 5.1683e-04 - accuracy: 1.0000 - val_loss: 4.4356e-04 - val_accuracy: 1.0000
# Epoch 87/100
# 22/22 [==============================] - 1s 43ms/step - loss: 5.2606e-04 - accuracy: 1.0000 - val_loss: 4.8718e-04 - val_accuracy: 1.0000
# Epoch 88/100
# 22/22 [==============================] - 1s 44ms/step - loss: 4.4334e-04 - accuracy: 1.0000 - val_loss: 5.6587e-04 - val_accuracy: 1.0000
# Epoch 89/100
# 22/22 [==============================] - 1s 41ms/step - loss: 5.5932e-04 - accuracy: 1.0000 - val_loss: 7.3398e-04 - val_accuracy: 1.0000
# Epoch 90/100
# 22/22 [==============================] - 1s 43ms/step - loss: 5.0773e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 91/100
# 22/22 [==============================] - 1s 40ms/step - loss: 5.1697e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 92/100
# 22/22 [==============================] - 1s 42ms/step - loss: 5.3558e-04 - accuracy: 1.0000 - val_loss: 8.6327e-04 - val_accuracy: 1.0000
# Epoch 93/100
# 22/22 [==============================] - 1s 42ms/step - loss: 4.1000e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 94/100
# 22/22 [==============================] - 1s 39ms/step - loss: 4.3586e-04 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 95/100
# 22/22 [==============================] - 1s 44ms/step - loss: 3.6363e-04 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 96/100
# 22/22 [==============================] - 1s 42ms/step - loss: 3.6328e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 97/100
# 22/22 [==============================] - 1s 43ms/step - loss: 4.0913e-04 - accuracy: 1.0000 - val_loss: 9.4872e-04 - val_accuracy: 1.0000
# Epoch 98/100
# 22/22 [==============================] - 1s 42ms/step - loss: 4.5016e-04 - accuracy: 1.0000 - val_loss: 8.9082e-04 - val_accuracy: 1.0000
# Epoch 99/100
# 22/22 [==============================] - 1s 41ms/step - loss: 4.7443e-04 - accuracy: 1.0000 - val_loss: 8.8333e-04 - val_accuracy: 1.0000
# Epoch 100/100
# 22/22 [==============================] - 1s 40ms/step - loss: 3.7595e-04 - accuracy: 1.0000 - val_loss: 8.9570e-04 - val_accuracy: 1.0000
# 2/2 [==============================] - 0s 22ms/step - loss: 2.3097e-04 - accuracy: 1.0000
# Accuracy on test set is: 1.0
# Expected index: 0, Predicted index: [0]

# %%
model.save('02_model/1121.h5')
# model=keras.models.load_model('02_model/1121.h5')

# %%
X_test_pre = model.predict(X_test)
y_pre = np.argmax(X_test_pre, axis = 1)

import sklearn.metrics as sm
matrixes = sm.confusion_matrix(y_test, y_pre)
print(matrixes)
report = sm.classification_report(y_test, y_pre)
print(report)
# Out:
# [[36  0]
#  [ 0  7]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        36
#            1       1.00      1.00      1.00         7
#
#     accuracy                           1.00        43
#    macro avg       1.00      1.00      1.00        43
# weighted avg       1.00      1.00      1.00        43

# %%
X_dev, y_dev = load_data("data_add.json")
y_dev_pre = np.argmax(model.predict(X_dev), axis = 1)
matrixes = sm.confusion_matrix(y_dev, y_dev_pre)
print(matrixes)
report = sm.classification_report(y_dev, y_dev_pre)
print(report)
# Out:
# [[780   2]
#  [  2  79]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       782
#            1       0.98      0.98      0.98        81
#
#     accuracy                           1.00       863
#    macro avg       0.99      0.99      0.99       863
# weighted avg       1.00      1.00      1.00       863

# %%
test_error, test_accuracy = model.evaluate(X_dev, y_dev, verbose = 1)
print("Accuracy on dev set is: {}".format(test_accuracy))
# Out:
# 27/27 [==============================] - 1s 24ms/step - loss: 0.0136 - accuracy: 0.9954
# Accuracy on dev set is: 0.9953650236129761
