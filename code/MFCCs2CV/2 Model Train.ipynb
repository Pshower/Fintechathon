# %% [markdown]
# # 2 Model Train
# - 使用CV方法做训练

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import matplotlib.pyplot as plt

DATA_PATH = "data_add.json"

def load_data(data_path):
    """Loads training dataset from json file
    
        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    
    """
    with open(data_path, "r") as fp:
        data = json.load(fp)
        
    X = np.array(data["mfcc"])
    y = np.array(data["labels"])
    return X, y

def prepare_datasets(test_size, validation_size):
    
    # load data
    X, y = load_data(DATA_PATH)
    
    # create train/test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = test_size)
    
    # create train/validation split
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size = validation_size)
    
    return (X_train, X_validation, X_test, y_train, y_validation, y_test)

def build_model(input_shape):
    """
    Generates RNN-LSTM model
    
    :param input_shape (tuple): Shape of input set
    :return model: RNN-LSTM model
    """
    
    # create model
    model = keras.Sequential()
    
    # 2 LSTM layers
    model.add(keras.layers.LSTM(64, input_shape = input_shape, return_sequences = True))
    model.add(keras.layers.LSTM(64))
    
    # dense layers
    model.add(keras.layers.Dense(64, activation = 'relu'))
    model.add(keras.layers.Dropout(0.3))
    
    # output layer
    model.add(keras.layers.Dense(10, activation = 'softmax'))
    
    return model
    
    
def plot_history(history):
    
    fig, axs = plt.subplots(2)
    
    # create accuracy subplot
    axs[0].plot(history.history["accuracy"], label = "train accuracy")
    axs[0].plot(history.history["val_accuracy"], label = "test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc = "lower right")
    axs[0].set_title("Accuracy eval")
    
    # create accuracy subplot
    axs[1].plot(history.history["loss"], label = "train error")
    axs[1].plot(history.history["val_loss"], label = "test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc = "upper right")
    axs[1].set_title("Error eval")
    
    plt.show()
    
def predict(model, X, y):
    
    X = X[np.newaxis, ...]
    
    # prediction = [ [0.1, 0.2, ...]]
    prediction = model.predict(X) # X -> (1, 130, 13, 1)
    
    # extract index with max value
    predicted_index = np.argmax(prediction, axis = 1) #[4]
    print("Expected index: {}, Predicted index: {}".format(y,  predicted_index))

# %%
if __name__ == "__main__":
    
    # create train, validation and test sets
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.25, 0.2)
    
    # build the CNN net
    input_shape = (X_train.shape[1], X_train.shape[2]) # 130, 13
    model = build_model(input_shape)
    
    # compile the network
    optimizer = keras.optimizers.Adam(learning_rate = 0.0001)
    model.compile(optimizer = optimizer, loss = "sparse_categorical_crossentropy", metrics = ['accuracy'])
    model.summary()
    
    # train the RNN-LSTM
    history = model.fit(X_train, y_train, validation_data = (X_validation, y_validation), batch_size = 32, epochs = 100)
    
    # evaluate the RNN-LSTM on the test set
    test_error, test_accuracy = model.evaluate(X_test, y_test, verbose = 1)
    print("Accuracy on test set is: {}".format(test_accuracy))
    
    # make prediction on a sample
    X = X_test[100]
    y = y_test[100]

    predict(model, X, y)
    
    # plot accuracy and error over the epochs
    plot_history(history)
# Out:
# 2024-11-21 11:15:08.039221: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-21 11:15:08.101825: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-21 11:15:08.102356: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-21 11:15:08.104976: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-21 11:15:08.107339: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-21 11:15:08.107930: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-21 11:15:08.108439: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-21 11:15:09.420116: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-21 11:15:09.420826: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-21 11:15:09.420840: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1609] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-11-21 11:15:09.421550: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-21 11:15:09.422054: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1613 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 259, 64)           19968
#
#  lstm_1 (LSTM)               (None, 64)                33024
#
#  dense (Dense)               (None, 64)                4160
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 57,802
# Trainable params: 57,802
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 2024-11-21 11:15:13.223533: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8101
# 2024-11-21 11:15:14.899178: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 17/17 [==============================] - 6s 71ms/step - loss: 2.1776 - accuracy: 0.2398 - val_loss: 2.0166 - val_accuracy: 0.7923
# Epoch 2/100
# 17/17 [==============================] - 1s 44ms/step - loss: 1.9205 - accuracy: 0.7060 - val_loss: 1.7672 - val_accuracy: 0.8769
# Epoch 3/100
# 17/17 [==============================] - 1s 45ms/step - loss: 1.6686 - accuracy: 0.8665 - val_loss: 1.5120 - val_accuracy: 0.8846
# Epoch 4/100
# 17/17 [==============================] - 1s 46ms/step - loss: 1.3859 - accuracy: 0.8897 - val_loss: 1.2428 - val_accuracy: 0.8846
# Epoch 5/100
# 17/17 [==============================] - 1s 44ms/step - loss: 1.1315 - accuracy: 0.9052 - val_loss: 0.9828 - val_accuracy: 0.8846
# Epoch 6/100
# 17/17 [==============================] - 1s 45ms/step - loss: 0.8750 - accuracy: 0.9033 - val_loss: 0.7558 - val_accuracy: 0.8846
# Epoch 7/100
# 17/17 [==============================] - 1s 44ms/step - loss: 0.6895 - accuracy: 0.9033 - val_loss: 0.5956 - val_accuracy: 0.8846
# Epoch 8/100
# 17/17 [==============================] - 1s 44ms/step - loss: 0.5196 - accuracy: 0.9033 - val_loss: 0.4958 - val_accuracy: 0.8846
# Epoch 9/100
# 17/17 [==============================] - 1s 45ms/step - loss: 0.4583 - accuracy: 0.9033 - val_loss: 0.4152 - val_accuracy: 0.8846
# Epoch 10/100
# 17/17 [==============================] - 1s 45ms/step - loss: 0.3646 - accuracy: 0.9130 - val_loss: 0.3612 - val_accuracy: 0.9000
# Epoch 11/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.3388 - accuracy: 0.9188 - val_loss: 0.3085 - val_accuracy: 0.9308
# Epoch 12/100
# 17/17 [==============================] - 1s 45ms/step - loss: 0.2711 - accuracy: 0.9458 - val_loss: 0.2628 - val_accuracy: 0.9385
# Epoch 13/100
# 17/17 [==============================] - 1s 44ms/step - loss: 0.2189 - accuracy: 0.9574 - val_loss: 0.2249 - val_accuracy: 0.9462
# Epoch 14/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.1858 - accuracy: 0.9594 - val_loss: 0.1474 - val_accuracy: 0.9538
# Epoch 15/100
# 17/17 [==============================] - 1s 46ms/step - loss: 0.1570 - accuracy: 0.9710 - val_loss: 0.1201 - val_accuracy: 0.9615
# Epoch 16/100
# 17/17 [==============================] - 1s 45ms/step - loss: 0.1305 - accuracy: 0.9729 - val_loss: 0.1044 - val_accuracy: 0.9615
# Epoch 17/100
# 17/17 [==============================] - 1s 49ms/step - loss: 0.1166 - accuracy: 0.9729 - val_loss: 0.0854 - val_accuracy: 0.9692
# Epoch 18/100
# 17/17 [==============================] - 1s 48ms/step - loss: 0.1116 - accuracy: 0.9826 - val_loss: 0.0900 - val_accuracy: 0.9692
# Epoch 19/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.0980 - accuracy: 0.9787 - val_loss: 0.0642 - val_accuracy: 0.9846
# Epoch 20/100
# 17/17 [==============================] - 1s 46ms/step - loss: 0.0858 - accuracy: 0.9826 - val_loss: 0.0751 - val_accuracy: 0.9769
# Epoch 21/100
# 17/17 [==============================] - 1s 48ms/step - loss: 0.0878 - accuracy: 0.9826 - val_loss: 0.0637 - val_accuracy: 0.9769
# Epoch 22/100
# 17/17 [==============================] - 1s 49ms/step - loss: 0.0769 - accuracy: 0.9865 - val_loss: 0.0545 - val_accuracy: 0.9846
# Epoch 23/100
# 17/17 [==============================] - 1s 51ms/step - loss: 0.0682 - accuracy: 0.9903 - val_loss: 0.0582 - val_accuracy: 0.9846
# Epoch 24/100
# 17/17 [==============================] - 1s 51ms/step - loss: 0.0490 - accuracy: 0.9923 - val_loss: 0.0481 - val_accuracy: 0.9846
# Epoch 25/100
# 17/17 [==============================] - 1s 46ms/step - loss: 0.0577 - accuracy: 0.9923 - val_loss: 0.0429 - val_accuracy: 0.9923
# Epoch 26/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.0517 - accuracy: 0.9961 - val_loss: 0.0416 - val_accuracy: 0.9923
# Epoch 27/100
# 17/17 [==============================] - 1s 44ms/step - loss: 0.0381 - accuracy: 0.9961 - val_loss: 0.0426 - val_accuracy: 0.9923
# Epoch 28/100
# 17/17 [==============================] - 1s 48ms/step - loss: 0.0298 - accuracy: 1.0000 - val_loss: 0.0335 - val_accuracy: 0.9923
# Epoch 29/100
# 17/17 [==============================] - 1s 48ms/step - loss: 0.0283 - accuracy: 0.9961 - val_loss: 0.0294 - val_accuracy: 0.9923
# Epoch 30/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.0259 - accuracy: 1.0000 - val_loss: 0.0277 - val_accuracy: 0.9923
# Epoch 31/100
# 17/17 [==============================] - 1s 45ms/step - loss: 0.0260 - accuracy: 1.0000 - val_loss: 0.0252 - val_accuracy: 0.9923
# Epoch 32/100
# 17/17 [==============================] - 1s 48ms/step - loss: 0.0220 - accuracy: 1.0000 - val_loss: 0.0238 - val_accuracy: 0.9923
# Epoch 33/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.0231 - accuracy: 1.0000 - val_loss: 0.0208 - val_accuracy: 0.9923
# Epoch 34/100
# 17/17 [==============================] - 1s 45ms/step - loss: 0.0194 - accuracy: 1.0000 - val_loss: 0.0181 - val_accuracy: 0.9923
# Epoch 35/100
# 17/17 [==============================] - 1s 46ms/step - loss: 0.0171 - accuracy: 1.0000 - val_loss: 0.0130 - val_accuracy: 1.0000
# Epoch 36/100
# 17/17 [==============================] - 1s 51ms/step - loss: 0.0162 - accuracy: 1.0000 - val_loss: 0.0109 - val_accuracy: 1.0000
# Epoch 37/100
# 17/17 [==============================] - 1s 43ms/step - loss: 0.0172 - accuracy: 1.0000 - val_loss: 0.0097 - val_accuracy: 1.0000
# Epoch 38/100
# 17/17 [==============================] - 1s 49ms/step - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.0078 - val_accuracy: 1.0000
# Epoch 39/100
# 17/17 [==============================] - 1s 46ms/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 0.0073 - val_accuracy: 1.0000
# Epoch 40/100
# 17/17 [==============================] - 1s 48ms/step - loss: 0.0150 - accuracy: 0.9981 - val_loss: 0.0065 - val_accuracy: 1.0000
# Epoch 41/100
# 17/17 [==============================] - 1s 46ms/step - loss: 0.0126 - accuracy: 1.0000 - val_loss: 0.0058 - val_accuracy: 1.0000
# Epoch 42/100
# 17/17 [==============================] - 1s 50ms/step - loss: 0.0109 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 1.0000
# Epoch 43/100
# 17/17 [==============================] - 1s 45ms/step - loss: 0.0115 - accuracy: 1.0000 - val_loss: 0.0054 - val_accuracy: 1.0000
# Epoch 44/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.0129 - accuracy: 1.0000 - val_loss: 0.0044 - val_accuracy: 1.0000
# Epoch 45/100
# 17/17 [==============================] - 1s 49ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.0040 - val_accuracy: 1.0000
# Epoch 46/100
# 17/17 [==============================] - 1s 46ms/step - loss: 0.0108 - accuracy: 1.0000 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 47/100
# 17/17 [==============================] - 1s 52ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 48/100
# 17/17 [==============================] - 1s 49ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 49/100
# 17/17 [==============================] - 1s 44ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 50/100
# 17/17 [==============================] - 1s 48ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 51/100
# 17/17 [==============================] - 1s 45ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 52/100
# 17/17 [==============================] - 1s 50ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 53/100
# 17/17 [==============================] - 1s 51ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 54/100
# 17/17 [==============================] - 1s 49ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 55/100
# 17/17 [==============================] - 1s 48ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 56/100
# 17/17 [==============================] - 1s 46ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 57/100
# 17/17 [==============================] - 1s 49ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 58/100
# 17/17 [==============================] - 1s 43ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 59/100
# 17/17 [==============================] - 1s 49ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 60/100
# 17/17 [==============================] - 1s 46ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 61/100
# 17/17 [==============================] - 1s 46ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 62/100
# 17/17 [==============================] - 1s 52ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 63/100
# 17/17 [==============================] - 1s 48ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 64/100
# 17/17 [==============================] - 1s 45ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 65/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 66/100
# 17/17 [==============================] - 1s 50ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 67/100
# 17/17 [==============================] - 1s 48ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 68/100
# 17/17 [==============================] - 1s 49ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 69/100
# 17/17 [==============================] - 1s 48ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 70/100
# 17/17 [==============================] - 1s 52ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 71/100
# 17/17 [==============================] - 1s 50ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 72/100
# 17/17 [==============================] - 1s 53ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 73/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 9.5882e-04 - val_accuracy: 1.0000
# Epoch 74/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 9.6261e-04 - val_accuracy: 1.0000
# Epoch 75/100
# 17/17 [==============================] - 1s 46ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 9.3028e-04 - val_accuracy: 1.0000
# Epoch 76/100
# 17/17 [==============================] - 1s 45ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 8.8687e-04 - val_accuracy: 1.0000
# Epoch 77/100
# 17/17 [==============================] - 1s 46ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 8.5008e-04 - val_accuracy: 1.0000
# Epoch 78/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 8.0531e-04 - val_accuracy: 1.0000
# Epoch 79/100
# 17/17 [==============================] - 1s 46ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 7.7080e-04 - val_accuracy: 1.0000
# Epoch 80/100
# 17/17 [==============================] - 1s 45ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 7.6233e-04 - val_accuracy: 1.0000
# Epoch 81/100
# 17/17 [==============================] - 1s 49ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 7.3092e-04 - val_accuracy: 1.0000
# Epoch 82/100
# 17/17 [==============================] - 1s 46ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 7.0167e-04 - val_accuracy: 1.0000
# Epoch 83/100
# 17/17 [==============================] - 1s 43ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 6.8731e-04 - val_accuracy: 1.0000
# Epoch 84/100
# 17/17 [==============================] - 1s 41ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 6.7370e-04 - val_accuracy: 1.0000
# Epoch 85/100
# 17/17 [==============================] - 1s 51ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 6.5089e-04 - val_accuracy: 1.0000
# Epoch 86/100
# 17/17 [==============================] - 1s 43ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 6.2559e-04 - val_accuracy: 1.0000
# Epoch 87/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 6.0607e-04 - val_accuracy: 1.0000
# Epoch 88/100
# 17/17 [==============================] - 1s 46ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 5.8453e-04 - val_accuracy: 1.0000
# Epoch 89/100
# 17/17 [==============================] - 1s 43ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 5.6488e-04 - val_accuracy: 1.0000
# Epoch 90/100
# 17/17 [==============================] - 1s 46ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 5.4539e-04 - val_accuracy: 1.0000
# Epoch 91/100
# 17/17 [==============================] - 1s 48ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 5.2372e-04 - val_accuracy: 1.0000
# Epoch 92/100
# 17/17 [==============================] - 1s 48ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 5.0396e-04 - val_accuracy: 1.0000
# Epoch 93/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 4.9209e-04 - val_accuracy: 1.0000
# Epoch 94/100
# 17/17 [==============================] - 1s 49ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 4.7372e-04 - val_accuracy: 1.0000
# Epoch 95/100
# 17/17 [==============================] - 1s 46ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 4.5957e-04 - val_accuracy: 1.0000
# Epoch 96/100
# 17/17 [==============================] - 1s 48ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 4.4392e-04 - val_accuracy: 1.0000
# Epoch 97/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 4.2870e-04 - val_accuracy: 1.0000
# Epoch 98/100
# 17/17 [==============================] - 1s 44ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 4.0989e-04 - val_accuracy: 1.0000
# Epoch 99/100
# 17/17 [==============================] - 1s 46ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 3.9771e-04 - val_accuracy: 1.0000
# Epoch 100/100
# 17/17 [==============================] - 1s 44ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 3.8908e-04 - val_accuracy: 1.0000
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0687 - accuracy: 0.9907
# Accuracy on test set is: 0.9907407164573669
# Expected index: 0, Predicted index: [0]
