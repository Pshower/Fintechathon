# %% [markdown]
# # 2 Model Train
# - 使用CV方法做训练

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import matplotlib.pyplot as plt

DATA_PATH = "data_add.json"

def load_data(data_path):
    """Loads training dataset from json file
    
        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    
    """
    with open(data_path, "r") as fp:
        data = json.load(fp)
        
    X = np.array(data["mfcc"])
    y = np.array(data["labels"])
    return X, y

def prepare_datasets(test_size, validation_size):
    
    # load data
    X, y = load_data(DATA_PATH)
    
    # create train/test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = test_size)
    
    # create train/validation split
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size = validation_size)
    
    return (X_train, X_validation, X_test, y_train, y_validation, y_test)

def build_model(input_shape):
    """
    Generates RNN-LSTM model
    
    :param input_shape (tuple): Shape of input set
    :return model: RNN-LSTM model
    """
    
    # create model
    model = keras.Sequential()
    
    # 3 LSTM layers
    model.add(keras.layers.LSTM(128, input_shape = input_shape, return_sequences = True))
    model.add(keras.layers.LSTM(64))
    
    # dense layers
    model.add(keras.layers.Dense(64, activation = 'relu'))
    model.add(keras.layers.Dropout(0.3))
    
    # output layer
    model.add(keras.layers.Dense(2, activation = 'softmax'))
    
    return model
    
    
def plot_history(history):
    
    fig, axs = plt.subplots(2)
    plt.figure(dpi=450)
    # create accuracy subplot
    axs[0].plot(history.history["accuracy"], label = "train accuracy")
    axs[0].plot(history.history["val_accuracy"], label = "test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc = "lower right")
    axs[0].set_title("Accuracy eval")
    
    # create accuracy subplot
    axs[1].plot(history.history["loss"], label = "train error")
    axs[1].plot(history.history["val_loss"], label = "test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc = "upper right")
    axs[1].set_title("Error eval")
    
    plt.show()
    
def predict(model, X, y):
    
    X = X[np.newaxis, ...]
    
    # prediction = [ [0.1, 0.2, ...]]
    prediction = model.predict(X) # X -> (1, 130, 13, 1)
    
    # extract index with max value
    predicted_index = np.argmax(prediction, axis = 1) #[4]
    print("Expected index: {}, Predicted index: {}".format(y,  predicted_index))

# %%
if __name__ == "__main__":
    
    # create train, validation and test sets
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.25, 0.2)
    
    # build the CNN net
    input_shape = (X_train.shape[1], X_train.shape[2]) # 130, 13
    model = build_model(input_shape)
    
    # compile the network
    optimizer = keras.optimizers.Adam(learning_rate = 0.0001)
    model.compile(optimizer = optimizer, loss = "sparse_categorical_crossentropy", metrics = ['accuracy'])
    model.summary()
    
    # train the RNN-LSTM
    history = model.fit(X_train, y_train, validation_data = (X_validation, y_validation), batch_size = 32, epochs = 100)
    
    # evaluate the RNN-LSTM on the test set
    test_error, test_accuracy = model.evaluate(X_test, y_test, verbose = 1)
    print("Accuracy on test set is: {}".format(test_accuracy))
    
    # make prediction on a sample
    X = X_test[100]
    y = y_test[100]

    predict(model, X, y)
    
    # plot accuracy and error over the epochs
    plot_history(history)
# Out:
# 2024-11-21 15:50:43.532692: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-21 15:50:43.557004: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-21 15:50:43.557725: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-21 15:50:43.558397: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-21 15:50:43.646109: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-21 15:50:43.647105: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-21 15:50:43.647770: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-21 15:50:44.792713: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-21 15:50:44.793464: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-21 15:50:44.793481: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1609] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-11-21 15:50:44.793972: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-21 15:50:44.794027: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1613 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 259, 128)          72704
#
#  lstm_1 (LSTM)               (None, 64)                49408
#
#  dense (Dense)               (None, 64)                4160
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 126,402
# Trainable params: 126,402
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 2024-11-21 15:50:48.001355: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8101
# 2024-11-21 15:50:49.410903: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 17/17 [==============================] - 6s 69ms/step - loss: 0.5357 - accuracy: 0.8124 - val_loss: 0.4180 - val_accuracy: 0.8769
# Epoch 2/100
# 17/17 [==============================] - 1s 45ms/step - loss: 0.3356 - accuracy: 0.9130 - val_loss: 0.3473 - val_accuracy: 0.8769
# Epoch 3/100
# 17/17 [==============================] - 1s 45ms/step - loss: 0.2971 - accuracy: 0.9130 - val_loss: 0.3359 - val_accuracy: 0.8769
# Epoch 4/100
# 17/17 [==============================] - 1s 48ms/step - loss: 0.2709 - accuracy: 0.9130 - val_loss: 0.3224 - val_accuracy: 0.8769
# Epoch 5/100
# 17/17 [==============================] - 1s 45ms/step - loss: 0.2470 - accuracy: 0.9130 - val_loss: 0.3040 - val_accuracy: 0.8769
# Epoch 6/100
# 17/17 [==============================] - 1s 43ms/step - loss: 0.2312 - accuracy: 0.9130 - val_loss: 0.2707 - val_accuracy: 0.8769
# Epoch 7/100
# 17/17 [==============================] - 1s 43ms/step - loss: 0.2116 - accuracy: 0.9188 - val_loss: 0.2380 - val_accuracy: 0.8769
# Epoch 8/100
# 17/17 [==============================] - 1s 48ms/step - loss: 0.1800 - accuracy: 0.9246 - val_loss: 0.1978 - val_accuracy: 0.8923
# Epoch 9/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.1497 - accuracy: 0.9381 - val_loss: 0.1554 - val_accuracy: 0.9154
# Epoch 10/100
# 17/17 [==============================] - 1s 46ms/step - loss: 0.1146 - accuracy: 0.9671 - val_loss: 0.1118 - val_accuracy: 0.9769
# Epoch 11/100
# 17/17 [==============================] - 1s 42ms/step - loss: 0.0815 - accuracy: 0.9826 - val_loss: 0.0795 - val_accuracy: 0.9846
# Epoch 12/100
# 17/17 [==============================] - 1s 44ms/step - loss: 0.0662 - accuracy: 0.9865 - val_loss: 0.0579 - val_accuracy: 0.9923
# Epoch 13/100
# 17/17 [==============================] - 1s 44ms/step - loss: 0.0458 - accuracy: 0.9961 - val_loss: 0.0426 - val_accuracy: 0.9923
# Epoch 14/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.0345 - accuracy: 0.9961 - val_loss: 0.0315 - val_accuracy: 1.0000
# Epoch 15/100
# 17/17 [==============================] - 1s 44ms/step - loss: 0.0260 - accuracy: 0.9981 - val_loss: 0.0250 - val_accuracy: 1.0000
# Epoch 16/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.0211 - accuracy: 1.0000 - val_loss: 0.0202 - val_accuracy: 1.0000
# Epoch 17/100
# 17/17 [==============================] - 1s 43ms/step - loss: 0.0174 - accuracy: 1.0000 - val_loss: 0.0164 - val_accuracy: 1.0000
# Epoch 18/100
# 17/17 [==============================] - 1s 45ms/step - loss: 0.0141 - accuracy: 1.0000 - val_loss: 0.0133 - val_accuracy: 1.0000
# Epoch 19/100
# 17/17 [==============================] - 1s 46ms/step - loss: 0.0131 - accuracy: 1.0000 - val_loss: 0.0112 - val_accuracy: 1.0000
# Epoch 20/100
# 17/17 [==============================] - 1s 46ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 0.0095 - val_accuracy: 1.0000
# Epoch 21/100
# 17/17 [==============================] - 1s 43ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 1.0000
# Epoch 22/100
# 17/17 [==============================] - 1s 43ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.0070 - val_accuracy: 1.0000
# Epoch 23/100
# 17/17 [==============================] - 1s 44ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.0060 - val_accuracy: 1.0000
# Epoch 24/100
# 17/17 [==============================] - 1s 45ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.0051 - val_accuracy: 1.0000
# Epoch 25/100
# 17/17 [==============================] - 1s 45ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.0044 - val_accuracy: 1.0000
# Epoch 26/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 27/100
# 17/17 [==============================] - 1s 43ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 28/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 29/100
# 17/17 [==============================] - 1s 49ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 30/100
# 17/17 [==============================] - 1s 46ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 31/100
# 17/17 [==============================] - 1s 49ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 32/100
# 17/17 [==============================] - 1s 46ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 33/100
# 17/17 [==============================] - 1s 45ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0121 - val_accuracy: 0.9923
# Epoch 34/100
# 17/17 [==============================] - 1s 45ms/step - loss: 0.0042 - accuracy: 0.9981 - val_loss: 0.0283 - val_accuracy: 0.9846
# Epoch 35/100
# 17/17 [==============================] - 1s 46ms/step - loss: 0.0151 - accuracy: 0.9981 - val_loss: 0.0438 - val_accuracy: 0.9846
# Epoch 36/100
# 17/17 [==============================] - 1s 45ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0088 - val_accuracy: 0.9923
# Epoch 37/100
# 17/17 [==============================] - 1s 44ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 38/100
# 17/17 [==============================] - 1s 49ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 39/100
# 17/17 [==============================] - 1s 48ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0115 - val_accuracy: 0.9923
# Epoch 40/100
# 17/17 [==============================] - 1s 48ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0193 - val_accuracy: 0.9923
# Epoch 41/100
# 17/17 [==============================] - 1s 46ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0177 - val_accuracy: 0.9923
# Epoch 42/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0131 - val_accuracy: 0.9923
# Epoch 43/100
# 17/17 [==============================] - 1s 45ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0097 - val_accuracy: 0.9923
# Epoch 44/100
# 17/17 [==============================] - 1s 44ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 0.9923
# Epoch 45/100
# 17/17 [==============================] - 1s 50ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 46/100
# 17/17 [==============================] - 1s 44ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 47/100
# 17/17 [==============================] - 1s 47ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 48/100
# 17/17 [==============================] - 1s 46ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 49/100
# 17/17 [==============================] - 1s 50ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 50/100
# 17/17 [==============================] - 1s 46ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 9.4571e-04 - val_accuracy: 1.0000
# Epoch 51/100
# 17/17 [==============================] - 1s 45ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 8.6231e-04 - val_accuracy: 1.0000
# Epoch 52/100
# 17/17 [==============================] - 1s 48ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 7.9082e-04 - val_accuracy: 1.0000
# Epoch 53/100
# 17/17 [==============================] - 1s 43ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 7.2919e-04 - val_accuracy: 1.0000
# Epoch 54/100
# 17/17 [==============================] - 1s 47ms/step - loss: 8.0445e-04 - accuracy: 1.0000 - val_loss: 6.8123e-04 - val_accuracy: 1.0000
# Epoch 55/100
# 17/17 [==============================] - 1s 56ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 6.3316e-04 - val_accuracy: 1.0000
# Epoch 56/100
# 17/17 [==============================] - 1s 44ms/step - loss: 7.9766e-04 - accuracy: 1.0000 - val_loss: 5.9944e-04 - val_accuracy: 1.0000
# Epoch 57/100
# 17/17 [==============================] - 1s 45ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 5.6488e-04 - val_accuracy: 1.0000
# Epoch 58/100
# 17/17 [==============================] - 1s 46ms/step - loss: 7.7641e-04 - accuracy: 1.0000 - val_loss: 5.3972e-04 - val_accuracy: 1.0000
# Epoch 59/100
# 17/17 [==============================] - 1s 45ms/step - loss: 8.6277e-04 - accuracy: 1.0000 - val_loss: 5.1822e-04 - val_accuracy: 1.0000
# Epoch 60/100
# 17/17 [==============================] - 1s 46ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 4.9675e-04 - val_accuracy: 1.0000
# Epoch 61/100
# 17/17 [==============================] - 1s 49ms/step - loss: 6.6341e-04 - accuracy: 1.0000 - val_loss: 4.7715e-04 - val_accuracy: 1.0000
# Epoch 62/100
# 17/17 [==============================] - 1s 45ms/step - loss: 9.9002e-04 - accuracy: 1.0000 - val_loss: 4.5709e-04 - val_accuracy: 1.0000
# Epoch 63/100
# 17/17 [==============================] - 1s 48ms/step - loss: 8.2855e-04 - accuracy: 1.0000 - val_loss: 4.3934e-04 - val_accuracy: 1.0000
# Epoch 64/100
# 17/17 [==============================] - 1s 49ms/step - loss: 7.2137e-04 - accuracy: 1.0000 - val_loss: 4.2552e-04 - val_accuracy: 1.0000
# Epoch 65/100
# 17/17 [==============================] - 1s 41ms/step - loss: 5.6207e-04 - accuracy: 1.0000 - val_loss: 4.1414e-04 - val_accuracy: 1.0000
# Epoch 66/100
# 17/17 [==============================] - 1s 45ms/step - loss: 7.7732e-04 - accuracy: 1.0000 - val_loss: 3.9517e-04 - val_accuracy: 1.0000
# Epoch 67/100
# 17/17 [==============================] - 1s 44ms/step - loss: 5.6584e-04 - accuracy: 1.0000 - val_loss: 3.7635e-04 - val_accuracy: 1.0000
# Epoch 68/100
# 17/17 [==============================] - 1s 46ms/step - loss: 5.6322e-04 - accuracy: 1.0000 - val_loss: 3.6474e-04 - val_accuracy: 1.0000
# Epoch 69/100
# 17/17 [==============================] - 1s 45ms/step - loss: 6.3980e-04 - accuracy: 1.0000 - val_loss: 3.4963e-04 - val_accuracy: 1.0000
# Epoch 70/100
# 17/17 [==============================] - 1s 48ms/step - loss: 5.3255e-04 - accuracy: 1.0000 - val_loss: 3.3840e-04 - val_accuracy: 1.0000
# Epoch 71/100
# 17/17 [==============================] - 1s 42ms/step - loss: 5.3951e-04 - accuracy: 1.0000 - val_loss: 3.1455e-04 - val_accuracy: 1.0000
# Epoch 72/100
# 17/17 [==============================] - 1s 46ms/step - loss: 6.0448e-04 - accuracy: 1.0000 - val_loss: 2.9761e-04 - val_accuracy: 1.0000
# Epoch 73/100
# 17/17 [==============================] - 1s 45ms/step - loss: 6.0039e-04 - accuracy: 1.0000 - val_loss: 2.8765e-04 - val_accuracy: 1.0000
# Epoch 74/100
# 17/17 [==============================] - 1s 46ms/step - loss: 7.3797e-04 - accuracy: 1.0000 - val_loss: 2.7481e-04 - val_accuracy: 1.0000
# Epoch 75/100
# 17/17 [==============================] - 1s 44ms/step - loss: 4.4809e-04 - accuracy: 1.0000 - val_loss: 2.6657e-04 - val_accuracy: 1.0000
# Epoch 76/100
# 17/17 [==============================] - 1s 46ms/step - loss: 4.4923e-04 - accuracy: 1.0000 - val_loss: 2.5717e-04 - val_accuracy: 1.0000
# Epoch 77/100
# 17/17 [==============================] - 1s 43ms/step - loss: 3.8556e-04 - accuracy: 1.0000 - val_loss: 2.4756e-04 - val_accuracy: 1.0000
# Epoch 78/100
# 17/17 [==============================] - 1s 43ms/step - loss: 4.6844e-04 - accuracy: 1.0000 - val_loss: 2.3727e-04 - val_accuracy: 1.0000
# Epoch 79/100
# 17/17 [==============================] - 1s 43ms/step - loss: 3.4685e-04 - accuracy: 1.0000 - val_loss: 2.3258e-04 - val_accuracy: 1.0000
# Epoch 80/100
# 17/17 [==============================] - 1s 48ms/step - loss: 5.2771e-04 - accuracy: 1.0000 - val_loss: 2.2442e-04 - val_accuracy: 1.0000
# Epoch 81/100
# 17/17 [==============================] - 1s 44ms/step - loss: 2.9922e-04 - accuracy: 1.0000 - val_loss: 2.1241e-04 - val_accuracy: 1.0000
# Epoch 82/100
# 17/17 [==============================] - 1s 46ms/step - loss: 4.3490e-04 - accuracy: 1.0000 - val_loss: 2.0512e-04 - val_accuracy: 1.0000
# Epoch 83/100
# 17/17 [==============================] - 1s 45ms/step - loss: 3.3557e-04 - accuracy: 1.0000 - val_loss: 2.0045e-04 - val_accuracy: 1.0000
# Epoch 84/100
# 17/17 [==============================] - 1s 44ms/step - loss: 3.3376e-04 - accuracy: 1.0000 - val_loss: 1.9140e-04 - val_accuracy: 1.0000
# Epoch 85/100
# 17/17 [==============================] - 1s 42ms/step - loss: 3.5914e-04 - accuracy: 1.0000 - val_loss: 1.7080e-04 - val_accuracy: 1.0000
# Epoch 86/100
# 17/17 [==============================] - 1s 46ms/step - loss: 3.4035e-04 - accuracy: 1.0000 - val_loss: 1.5719e-04 - val_accuracy: 1.0000
# Epoch 87/100
# 17/17 [==============================] - 1s 46ms/step - loss: 2.8379e-04 - accuracy: 1.0000 - val_loss: 1.5040e-04 - val_accuracy: 1.0000
# Epoch 88/100
# 17/17 [==============================] - 1s 44ms/step - loss: 2.3324e-04 - accuracy: 1.0000 - val_loss: 1.4508e-04 - val_accuracy: 1.0000
# Epoch 89/100
# 17/17 [==============================] - 1s 45ms/step - loss: 3.6449e-04 - accuracy: 1.0000 - val_loss: 1.3949e-04 - val_accuracy: 1.0000
# Epoch 90/100
# 17/17 [==============================] - 1s 44ms/step - loss: 2.9802e-04 - accuracy: 1.0000 - val_loss: 1.3308e-04 - val_accuracy: 1.0000
# Epoch 91/100
# 17/17 [==============================] - 1s 42ms/step - loss: 4.3534e-04 - accuracy: 1.0000 - val_loss: 1.2604e-04 - val_accuracy: 1.0000
# Epoch 92/100
# 17/17 [==============================] - 1s 45ms/step - loss: 1.8427e-04 - accuracy: 1.0000 - val_loss: 1.2247e-04 - val_accuracy: 1.0000
# Epoch 93/100
# 17/17 [==============================] - 1s 47ms/step - loss: 2.0552e-04 - accuracy: 1.0000 - val_loss: 1.1980e-04 - val_accuracy: 1.0000
# Epoch 94/100
# 17/17 [==============================] - 1s 45ms/step - loss: 2.7771e-04 - accuracy: 1.0000 - val_loss: 1.1715e-04 - val_accuracy: 1.0000
# Epoch 95/100
# 17/17 [==============================] - 1s 43ms/step - loss: 3.2919e-04 - accuracy: 1.0000 - val_loss: 1.1633e-04 - val_accuracy: 1.0000
# Epoch 96/100
# 17/17 [==============================] - 1s 44ms/step - loss: 2.4753e-04 - accuracy: 1.0000 - val_loss: 1.1683e-04 - val_accuracy: 1.0000
# Epoch 97/100
# 17/17 [==============================] - 1s 42ms/step - loss: 2.9408e-04 - accuracy: 1.0000 - val_loss: 1.1839e-04 - val_accuracy: 1.0000
# Epoch 98/100
# 17/17 [==============================] - 1s 41ms/step - loss: 3.0740e-04 - accuracy: 1.0000 - val_loss: 1.4468e-04 - val_accuracy: 1.0000
# Epoch 99/100
# 17/17 [==============================] - 1s 40ms/step - loss: 3.4756e-04 - accuracy: 1.0000 - val_loss: 2.1666e-04 - val_accuracy: 1.0000
# Epoch 100/100
# 17/17 [==============================] - 1s 43ms/step - loss: 2.5659e-04 - accuracy: 1.0000 - val_loss: 3.8304e-04 - val_accuracy: 1.0000
# 7/7 [==============================] - 0s 19ms/step - loss: 6.7316e-05 - accuracy: 1.0000
# Accuracy on test set is: 1.0
# Expected index: 0, Predicted index: [0]

# %%
X_test_pre = model.predict(X_test)
y_pre = np.argmax(X_test_pre, axis = 1)

import sklearn.metrics as sm
matrixes = sm.confusion_matrix(y_test, y_pre)
print(matrixes)
report = sm.classification_report(y_test, y_pre)
print(report)
# Out:
# [[196   0]
#  [  0  20]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       196
#            1       1.00      1.00      1.00        20
#
#     accuracy                           1.00       216
#    macro avg       1.00      1.00      1.00       216
# weighted avg       1.00      1.00      1.00       216
